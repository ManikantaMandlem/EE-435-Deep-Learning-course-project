# %% [markdown]
# <a href="https://colab.research.google.com/github/ManikantaMandlem/EE-435-Deep-Learning-course-project/blob/main/DLFAA_project2_experiment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import os
from collections import defaultdict
import numpy as np
import random
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torchvision.models as models
from torchsummary import summary
import torch.nn as nn

# %%
params = {
    'batchsize' : 16,
    'shuffle' : True,
    'num_workers' : 8,
    'lr' : 0.0001,
    'epochs' : 30
}

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# threshold = 5
#
# min_images = 2
#
# os.walk(filter for folders more than threshold)
#
# create train, valid1, valid2, test1 and test2
#
# 1 - people that are already seen by model
#
# 2 - people that are not seen by model
#
# to create 1, move first min_images of a person to train and the rest is assigned randomly with probabilities of 90-5-5 to valid1 and test1
#
# for 2, split the test dataset into to build valid2 and test2
# create dataset objects for all 5 and create dataloads for all 5
#
# Download and save resnet model, change the fully connected layer (add fully connected layers if necessary)
#
# Train, validate and test the model....hooray..! :)

# %%
person_dir = []
person_img_path = defaultdict(list)
threshold = 4
# imagesplit_thr = 2
mypath = '/content/drive/MyDrive/DLFAA/Final_Project/lfw'
dirnames = os.listdir(mypath)
dirnames.pop(5000)
for dirname in dirnames:
    path = mypath +'/'+ dirname
    person_img_path[path] = os.listdir(path)

# %%
type1_dict = defaultdict(list)
type2_dict = defaultdict(list)

file1 = open('/content/drive/MyDrive/DLFAA/Final_Project/train.txt', 'r')
file2 = open('/content/drive/MyDrive/DLFAA/Final_Project/test.txt', 'r')

for line in file1:
    type1_dict[mypath +'/' + line.strip()] = person_img_path[mypath +'/' + line.strip()]
for line in file2:
    type2_dict[mypath +'/' + line.strip()] = person_img_path[mypath +'/' + line.strip()]

# %%
print(mypath + '/'+'Leszek_Miller')
print(type1_dict)
# Out:
# /content/drive/MyDrive/DLFAA/Final_Project/lfw/Leszek_Miller
# defaultdict(<class 'list'>, {'/content/drive/MyDrive/DLFAA/Final_Project/lfw/AJ_Cook': ['AJ_Cook_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aaron_Eckhart': ['Aaron_Eckhart_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aaron_Patterson': ['Aaron_Patterson_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aaron_Peirsol': ['Aaron_Peirsol_0001.jpg', 'Aaron_Peirsol_0002.jpg', 'Aaron_Peirsol_0003.jpg', 'Aaron_Peirsol_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aaron_Pena': ['Aaron_Pena_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aaron_Sorkin': ['Aaron_Sorkin_0001.jpg', 'Aaron_Sorkin_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abbas_Kiarostami': ['Abbas_Kiarostami_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdel_Aziz_Al-Hakim': ['Abdel_Aziz_Al-Hakim_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdel_Madi_Shabneh': ['Abdel_Madi_Shabneh_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdel_Nasser_Assidi': ['Abdel_Nasser_Assidi_0001.jpg', 'Abdel_Nasser_Assidi_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdoulaye_Wade': ['Abdoulaye_Wade_0001.jpg', 'Abdoulaye_Wade_0002.jpg', 'Abdoulaye_Wade_0003.jpg', 'Abdoulaye_Wade_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdul_Rahman': ['Abdul_Rahman_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullah': ['Abdullah_0001.jpg', 'Abdullah_0002.jpg', 'Abdullah_0003.jpg', 'Abdullah_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullah_Ahmad_Badawi': ['Abdullah_Ahmad_Badawi_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullah_Nasseef': ['Abdullah_Nasseef_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullah_al-Attiyah': ['Abdullah_al-Attiyah_0001.jpg', 'Abdullah_al-Attiyah_0002.jpg', 'Abdullah_al-Attiyah_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abel_Pacheco': ['Abel_Pacheco_0001.jpg', 'Abel_Pacheco_0002.jpg', 'Abel_Pacheco_0003.jpg', 'Abel_Pacheco_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abner_Martinez': ['Abner_Martinez_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abraham_Foxman': ['Abraham_Foxman_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aby_Har-Even': ['Aby_Har-Even_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Freier': ['Adam_Freier_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Herbert': ['Adam_Herbert_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Mair': ['Adam_Mair_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Rich': ['Adam_Rich_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Sandler': ['Adam_Sandler_0001.jpg', 'Adam_Sandler_0002.jpg', 'Adam_Sandler_0003.jpg', 'Adam_Sandler_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Scott': ['Adam_Scott_0001.jpg', 'Adam_Scott_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adelina_Avila': ['Adelina_Avila_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adisai_Bodharamik': ['Adisai_Bodharamik_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adolfo_Aguilar_Zinser': ['Adolfo_Aguilar_Zinser_0001.jpg', 'Adolfo_Aguilar_Zinser_0002.jpg', 'Adolfo_Aguilar_Zinser_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adolfo_Rodriguez_Saa': ['Adolfo_Rodriguez_Saa_0001.jpg', 'Adolfo_Rodriguez_Saa_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adoor_Gopalakarishnan': ['Adoor_Gopalakarishnan_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrian_Fernandez': ['Adrian_Fernandez_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrian_McPherson': ['Adrian_McPherson_0001.jpg', 'Adrian_McPherson_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrian_Nastase': ['Adrian_Nastase_0001.jpg', 'Adrian_Nastase_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrianna_Zuzic': ['Adrianna_Zuzic_00 ...

# %%
print(len(type1_dict))
del_list = []
for names in type1_dict.keys():
    if len(type1_dict[names]) < threshold:
        del_list.append(names)
for name in del_list:
    del type1_dict[name]
print(len(del_list))
# Out:
# 4038
# 3607

# %%
type2_val = defaultdict(list)
type2_test = defaultdict(list)

for name in type2_dict.keys():
    size = len(type2_dict[name])
    if len(type2_dict[name]) >= 2:
        type2_val[name].extend(type2_dict[name][:size//2]) # 7  -  0, 3
        type2_test[name].extend(type2_dict[name][size//2 : size - size%2]) # 3, 6
    if size % 2:
        if np.random.rand() < 0.5:
            type2_val[name].append(type2_dict[name][-1])
        else:
            type2_test[name].append(type2_dict[name][-1])
print(type2_dict)
print(type2_val)
print(type2_test)
# Out:
# defaultdict(<class 'list'>, {'/content/drive/MyDrive/DLFAA/Final_Project/lfw/AJ_Lamas': ['AJ_Lamas_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aaron_Guiel': ['Aaron_Guiel_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aaron_Tippin': ['Aaron_Tippin_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abba_Eban': ['Abba_Eban_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdul_Majeed_Shobokshi': ['Abdul_Majeed_Shobokshi_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdulaziz_Kamilov': ['Abdulaziz_Kamilov_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullah_Gul': ['Abdullah_Gul_0001.jpg', 'Abdullah_Gul_0002.jpg', 'Abdullah_Gul_0003.jpg', 'Abdullah_Gul_0004.jpg', 'Abdullah_Gul_0006.jpg', 'Abdullah_Gul_0005.jpg', 'Abdullah_Gul_0007.jpg', 'Abdullah_Gul_0008.jpg', 'Abdullah_Gul_0009.jpg', 'Abdullah_Gul_0010.jpg', 'Abdullah_Gul_0011.jpg', 'Abdullah_Gul_0012.jpg', 'Abdullah_Gul_0013.jpg', 'Abdullah_Gul_0014.jpg', 'Abdullah_Gul_0015.jpg', 'Abdullah_Gul_0016.jpg', 'Abdullah_Gul_0017.jpg', 'Abdullah_Gul_0018.jpg', 'Abdullah_Gul_0019.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullatif_Sener': ['Abdullatif_Sener_0001.jpg', 'Abdullatif_Sener_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abel_Aguilar': ['Abel_Aguilar_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abid_Hamid_Mahmud_Al-Tikriti': ['Abid_Hamid_Mahmud_Al-Tikriti_0002.jpg', 'Abid_Hamid_Mahmud_Al-Tikriti_0001.jpg', 'Abid_Hamid_Mahmud_Al-Tikriti_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Ant': ['Adam_Ant_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Kennedy': ['Adam_Kennedy_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adel_Al-Jubeir': ['Adel_Al-Jubeir_0001.jpg', 'Adel_Al-Jubeir_0002.jpg', 'Adel_Al-Jubeir_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrian_Annus': ['Adrian_Annus_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrian_Murrell': ['Adrian_Murrell_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adriana_Lima': ['Adriana_Lima_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adriana_Perez_Navarro': ['Adriana_Perez_Navarro_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrien_Brody': ['Adrien_Brody_0001.jpg', 'Adrien_Brody_0002.jpg', 'Adrien_Brody_0003.jpg', 'Adrien_Brody_0004.jpg', 'Adrien_Brody_0005.jpg', 'Adrien_Brody_0006.jpg', 'Adrien_Brody_0007.jpg', 'Adrien_Brody_0008.jpg', 'Adrien_Brody_0009.jpg', 'Adrien_Brody_0010.jpg', 'Adrien_Brody_0011.jpg', 'Adrien_Brody_0012.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Agbani_Darego': ['Agbani_Darego_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Agnelo_Queiroz': ['Agnelo_Queiroz_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ahmed_Ghazi': ['Ahmed_Ghazi_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aileen_Riggin_Soule': ['Aileen_Riggin_Soule_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ain_Seppik': ['Ain_Seppik_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aitor_Gonzalez': ['Aitor_Gonzalez_0001.jpg', 'Aitor_Gonzalez_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Cardenas': ['Al_Cardenas_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Davis': ['Al_Davis_0001.jpg', 'Al_Davis_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Pacino': ['Al_Pacino_0001.jpg', 'Al_Pacino_0002.jpg', 'Al_Pacino_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alan_Dershowitz': ['Alan_Dershowitz_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alan_Greenspan': ['Alan_Greenspan_0001.jpg', 'Alan_Greenspan_0002.jpg', 'Alan_Greenspan_0003.jpg', 'Alan_Greenspan_0004.jpg', 'Alan_Greenspan_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alan_Stonecipher': ['Alan_Stonecipher_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alan_Zemaitis': ['Alan_Zemaitis_0001.jpg' ...
# defaultdict(<class 'list'>, {'/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aaron_Tippin': ['Aaron_Tippin_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abba_Eban': ['Abba_Eban_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdul_Majeed_Shobokshi': ['Abdul_Majeed_Shobokshi_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdulaziz_Kamilov': ['Abdulaziz_Kamilov_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullah_Gul': ['Abdullah_Gul_0001.jpg', 'Abdullah_Gul_0002.jpg', 'Abdullah_Gul_0003.jpg', 'Abdullah_Gul_0004.jpg', 'Abdullah_Gul_0006.jpg', 'Abdullah_Gul_0005.jpg', 'Abdullah_Gul_0007.jpg', 'Abdullah_Gul_0008.jpg', 'Abdullah_Gul_0009.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullatif_Sener': ['Abdullatif_Sener_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abid_Hamid_Mahmud_Al-Tikriti': ['Abid_Hamid_Mahmud_Al-Tikriti_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adel_Al-Jubeir': ['Adel_Al-Jubeir_0001.jpg', 'Adel_Al-Jubeir_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adriana_Perez_Navarro': ['Adriana_Perez_Navarro_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrien_Brody': ['Adrien_Brody_0001.jpg', 'Adrien_Brody_0002.jpg', 'Adrien_Brody_0003.jpg', 'Adrien_Brody_0004.jpg', 'Adrien_Brody_0005.jpg', 'Adrien_Brody_0006.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Agbani_Darego': ['Agbani_Darego_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aitor_Gonzalez': ['Aitor_Gonzalez_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Davis': ['Al_Davis_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Pacino': ['Al_Pacino_0001.jpg', 'Al_Pacino_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alan_Greenspan': ['Alan_Greenspan_0001.jpg', 'Alan_Greenspan_0002.jpg', 'Alan_Greenspan_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Albert_Costa': ['Albert_Costa_0001.jpg', 'Albert_Costa_0002.jpg', 'Albert_Costa_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alecos_Markides': ['Alecos_Markides_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alejandro_Atchugarry': ['Alejandro_Atchugarry_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alejandro_Fernandez': ['Alejandro_Fernandez_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aleksander_Kwasniewski': ['Aleksander_Kwasniewski_0001.jpg', 'Aleksander_Kwasniewski_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aleksander_Voloshin': ['Aleksander_Voloshin_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alex_Cabrera': ['Alex_Cabrera_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alex_Corretja': ['Alex_Corretja_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alex_Penelas': ['Alex_Penelas_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alexandra_Pelosi': ['Alexandra_Pelosi_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alexandra_Rozovskaya': ['Alexandra_Rozovskaya_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alfonso_Portillo': ['Alfonso_Portillo_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ali_Fallahian': ['Ali_Fallahian_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ali_Mohammed_Maher': ['Ali_Mohammed_Maher_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ali_Naimi': ['Ali_Naimi_0001.jpg', 'Ali_Naimi_0002.jpg', 'Ali_Naimi_0003.jpg', 'Ali_Naimi_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aline_Chretien': ['Aline_Chretien_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alisha_Richman': ['Alisha_Richman_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Allison_Janney': ['Allison_Janney_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Allison_Searing': ['Allison_Searing_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Allyson_Felix': ['Allyson_Felix_0001.jpg', 'Allyson_Felix_0002.jpg'], '/ ...
# defaultdict(<class 'list'>, {'/content/drive/MyDrive/DLFAA/Final_Project/lfw/AJ_Lamas': ['AJ_Lamas_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aaron_Guiel': ['Aaron_Guiel_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullah_Gul': ['Abdullah_Gul_0010.jpg', 'Abdullah_Gul_0011.jpg', 'Abdullah_Gul_0012.jpg', 'Abdullah_Gul_0013.jpg', 'Abdullah_Gul_0014.jpg', 'Abdullah_Gul_0015.jpg', 'Abdullah_Gul_0016.jpg', 'Abdullah_Gul_0017.jpg', 'Abdullah_Gul_0018.jpg', 'Abdullah_Gul_0019.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullatif_Sener': ['Abdullatif_Sener_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abel_Aguilar': ['Abel_Aguilar_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abid_Hamid_Mahmud_Al-Tikriti': ['Abid_Hamid_Mahmud_Al-Tikriti_0001.jpg', 'Abid_Hamid_Mahmud_Al-Tikriti_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Ant': ['Adam_Ant_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Kennedy': ['Adam_Kennedy_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adel_Al-Jubeir': ['Adel_Al-Jubeir_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrian_Annus': ['Adrian_Annus_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrian_Murrell': ['Adrian_Murrell_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adriana_Lima': ['Adriana_Lima_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adrien_Brody': ['Adrien_Brody_0007.jpg', 'Adrien_Brody_0008.jpg', 'Adrien_Brody_0009.jpg', 'Adrien_Brody_0010.jpg', 'Adrien_Brody_0011.jpg', 'Adrien_Brody_0012.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Agnelo_Queiroz': ['Agnelo_Queiroz_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ahmed_Ghazi': ['Ahmed_Ghazi_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aileen_Riggin_Soule': ['Aileen_Riggin_Soule_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ain_Seppik': ['Ain_Seppik_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aitor_Gonzalez': ['Aitor_Gonzalez_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Cardenas': ['Al_Cardenas_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Davis': ['Al_Davis_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Pacino': ['Al_Pacino_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alan_Dershowitz': ['Alan_Dershowitz_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alan_Greenspan': ['Alan_Greenspan_0003.jpg', 'Alan_Greenspan_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alan_Stonecipher': ['Alan_Stonecipher_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alan_Zemaitis': ['Alan_Zemaitis_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Albert_Costa': ['Albert_Costa_0004.jpg', 'Albert_Costa_0005.jpg', 'Albert_Costa_0006.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alejandro_Atchugarry': ['Alejandro_Atchugarry_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aleksander_Kwasniewski': ['Aleksander_Kwasniewski_0003.jpg', 'Aleksander_Kwasniewski_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alessandro_Nesta': ['Alessandro_Nesta_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alex_Penelas': ['Alex_Penelas_0002.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alex_Zanardi': ['Alex_Zanardi_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alexis_Dennisoff': ['Alexis_Dennisoff_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alfonso_Soriano': ['Alfonso_Soriano_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ali_Naimi': ['Ali_Naimi_0005.jpg', 'Ali_Naimi_0006.jpg', 'Ali_Naimi_0007.jpg', 'Ali_Naimi_0008.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alicia_Keys': ['Alicia_Keys_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alicia_Molik': ['Alicia_Molik_0001.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Allen_Rock': [ ...

# %%
train = defaultdict(list)
type1_val = defaultdict(list)
type1_test = defaultdict(list)

for name in type1_dict.keys():
    size = len(type1_dict[name])
    #if size > imagesplit_thr:
    train[name] = type1_dict[name][:int(size*0.8)]
    size2 = size - int(size*0.8)
    #for image in type1_dict[name][size*0.8:]:
    if size2 >= 2:
        type1_val[name].extend(type1_dict[name][int(size*0.8):int(size*0.8)+size2//2]) 
        type1_test[name].extend(type1_dict[name][int(size*0.8)+size2//2 : size - size2%2])
    if size2 % 2:
        if np.random.rand() < 0.5:
            type1_val[name].append(type1_dict[name][-1])
        else:
            type1_test[name].append(type1_dict[name][-1])

print(train)
print(type1_val)
# Out:
# defaultdict(<class 'list'>, {'/content/drive/MyDrive/DLFAA/Final_Project/lfw/Aaron_Peirsol': ['Aaron_Peirsol_0001.jpg', 'Aaron_Peirsol_0002.jpg', 'Aaron_Peirsol_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdoulaye_Wade': ['Abdoulaye_Wade_0001.jpg', 'Abdoulaye_Wade_0002.jpg', 'Abdoulaye_Wade_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abdullah': ['Abdullah_0001.jpg', 'Abdullah_0002.jpg', 'Abdullah_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abel_Pacheco': ['Abel_Pacheco_0001.jpg', 'Abel_Pacheco_0002.jpg', 'Abel_Pacheco_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Adam_Sandler': ['Adam_Sandler_0001.jpg', 'Adam_Sandler_0002.jpg', 'Adam_Sandler_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ahmed_Chalabi': ['Ahmed_Chalabi_0001.jpg', 'Ahmed_Chalabi_0002.jpg', 'Ahmed_Chalabi_0003.jpg', 'Ahmed_Chalabi_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ai_Sugiyama': ['Ai_Sugiyama_0001.jpg', 'Ai_Sugiyama_0002.jpg', 'Ai_Sugiyama_0003.jpg', 'Ai_Sugiyama_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Gore': ['Al_Gore_0001.jpg', 'Al_Gore_0002.jpg', 'Al_Gore_0003.jpg', 'Al_Gore_0004.jpg', 'Al_Gore_0005.jpg', 'Al_Gore_0006.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Sharpton': ['Al_Sharpton_0001.jpg', 'Al_Sharpton_0002.jpg', 'Al_Sharpton_0003.jpg', 'Al_Sharpton_0004.jpg', 'Al_Sharpton_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alastair_Campbell': ['Alastair_Campbell_0001.jpg', 'Alastair_Campbell_0002.jpg', 'Alastair_Campbell_0003.jpg', 'Alastair_Campbell_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alec_Baldwin': ['Alec_Baldwin_0001.jpg', 'Alec_Baldwin_0002.jpg', 'Alec_Baldwin_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alejandro_Toledo': ['Alejandro_Toledo_0001.jpg', 'Alejandro_Toledo_0002.jpg', 'Alejandro_Toledo_0003.jpg', 'Alejandro_Toledo_0004.jpg', 'Alejandro_Toledo_0005.jpg', 'Alejandro_Toledo_0006.jpg', 'Alejandro_Toledo_0007.jpg', 'Alejandro_Toledo_0008.jpg', 'Alejandro_Toledo_0009.jpg', 'Alejandro_Toledo_0010.jpg', 'Alejandro_Toledo_0011.jpg', 'Alejandro_Toledo_0012.jpg', 'Alejandro_Toledo_0013.jpg', 'Alejandro_Toledo_0014.jpg', 'Alejandro_Toledo_0015.jpg', 'Alejandro_Toledo_0016.jpg', 'Alejandro_Toledo_0017.jpg', 'Alejandro_Toledo_0018.jpg', 'Alejandro_Toledo_0019.jpg', 'Alejandro_Toledo_0021.jpg', 'Alejandro_Toledo_0020.jpg', 'Alejandro_Toledo_0023.jpg', 'Alejandro_Toledo_0022.jpg', 'Alejandro_Toledo_0024.jpg', 'Alejandro_Toledo_0025.jpg', 'Alejandro_Toledo_0026.jpg', 'Alejandro_Toledo_0027.jpg', 'Alejandro_Toledo_0028.jpg', 'Alejandro_Toledo_0029.jpg', 'Alejandro_Toledo_0030.jpg', 'Alejandro_Toledo_0032.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alexander_Downer': ['Alexander_Downer_0001.jpg', 'Alexander_Downer_0002.jpg', 'Alexander_Downer_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alexander_Losyukov': ['Alexander_Losyukov_0001.jpg', 'Alexander_Losyukov_0002.jpg', 'Alexander_Losyukov_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alvaro_Silva_Calderon': ['Alvaro_Silva_Calderon_0001.jpg', 'Alvaro_Silva_Calderon_0002.jpg', 'Alvaro_Silva_Calderon_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Amelia_Vega': ['Amelia_Vega_0001.jpg', 'Amelia_Vega_0002.jpg', 'Amelia_Vega_0003.jpg', 'Amelia_Vega_0004.jpg', 'Amelia_Vega_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Amer_al-Saadi': ['Amer_al-Saadi_0001.jpg', 'Amer_al-Saadi_0002.jpg', 'Amer_al-Saadi_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ana_Guevara': ['Ana_Guevara_0001.jpg', 'Ana_Guevara_0002.jpg', 'Ana_Guevara_0003.jpg', 'Ana_Guevara_0004.jpg', 'Ana_Guevara_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Anders_Fogh_Rasmussen': ['Anders_Fogh_Rasmussen_0001.jpg', 'Anders_Fogh_Rasmussen_0002.jpg', 'Anders_Fogh_Rasmussen_0003.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Andre_Agassi': ['Andre_Agassi_0001.jpg', 'Andre_Aga ...
# defaultdict(<class 'list'>, {'/content/drive/MyDrive/DLFAA/Final_Project/lfw/Abel_Pacheco': ['Abel_Pacheco_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ahmed_Chalabi': ['Ahmed_Chalabi_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ai_Sugiyama': ['Ai_Sugiyama_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Gore': ['Al_Gore_0008.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Al_Sharpton': ['Al_Sharpton_0006.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alastair_Campbell': ['Alastair_Campbell_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alec_Baldwin': ['Alec_Baldwin_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alejandro_Toledo': ['Alejandro_Toledo_0031.jpg', 'Alejandro_Toledo_0034.jpg', 'Alejandro_Toledo_0033.jpg', 'Alejandro_Toledo_0035.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alexander_Losyukov': ['Alexander_Losyukov_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Alvaro_Silva_Calderon': ['Alvaro_Silva_Calderon_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Amelia_Vega': ['Amelia_Vega_0006.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ana_Guevara': ['Ana_Guevara_0006.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Anders_Fogh_Rasmussen': ['Anders_Fogh_Rasmussen_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Andre_Agassi': ['Andre_Agassi_0029.jpg', 'Andre_Agassi_0030.jpg', 'Andre_Agassi_0031.jpg', 'Andre_Agassi_0032.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Andy_Roddick': ['Andy_Roddick_0013.jpg', 'Andy_Roddick_0014.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Angela_Bassett': ['Angela_Bassett_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Angela_Merkel': ['Angela_Merkel_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Angelina_Jolie': ['Angelina_Jolie_0017.jpg', 'Angelina_Jolie_0018.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Anna_Kournikova': ['Anna_Kournikova_0010.jpg', 'Anna_Kournikova_0012.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Antonio_Banderas': ['Antonio_Banderas_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ari_Fleischer': ['Ari_Fleischer_0011.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ariel_Sharon': ['Ariel_Sharon_0061.jpg', 'Ariel_Sharon_0063.jpg', 'Ariel_Sharon_0064.jpg', 'Ariel_Sharon_0065.jpg', 'Ariel_Sharon_0066.jpg', 'Ariel_Sharon_0067.jpg', 'Ariel_Sharon_0068.jpg', 'Ariel_Sharon_0069.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Arminio_Fraga': ['Arminio_Fraga_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Arnold_Schwarzenegger': ['Arnold_Schwarzenegger_0034.jpg', 'Arnold_Schwarzenegger_0035.jpg', 'Arnold_Schwarzenegger_0037.jpg', 'Arnold_Schwarzenegger_0036.jpg', 'Arnold_Schwarzenegger_0042.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Arnoldo_Aleman': ['Arnoldo_Aleman_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Atal_Bihari_Vajpayee': ['Atal_Bihari_Vajpayee_0020.jpg', 'Atal_Bihari_Vajpayee_0021.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Barbara_Walters': ['Barbara_Walters_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Benazir_Bhutto': ['Benazir_Bhutto_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Bernard_Landry': ['Bernard_Landry_0004.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Bernard_Law': ['Bernard_Law_0005.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Bill_Clinton': ['Bill_Clinton_0024.jpg', 'Bill_Clinton_0025.jpg', 'Bill_Clinton_0026.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Bill_Gates': ['Bill_Gates_0014.jpg', 'Bill_Gates_0015.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Bill_Graham': ['Bill_Graham_0008.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Bill_Simon': ['Bill_Simon_0013.jpg', 'Bill_Simon_0015.jpg'], '/content/drive/MyDrive/DLFAA/Final_Project/lfw/Billy_Crystal': ['Billy_Crystal_0005.jpg'], '/content/drive/MyD ...

# %%
person_mapping = {}
i = 0
for path in train:
    person_mapping[path.split('/')[-1]] = i
    i+=1
for path in type2_val:
    person_mapping[path.split('/')[-1]] = i
    i+=1
for path in type2_test:
    person_mapping[path.split('/')[-1]] = i
    i+=1

# %%
def get_data(dataset):
    data = []
    for path in dataset:
        for image in dataset[path]:
            data.append([path+'/'+image,person_mapping[path.split('/')[-1]]])
    return data

# %%
data_train_todataset = get_data(train)
print(len(data_train_todataset))

data_val1_todataset = get_data(type1_val)
print(len(data_val1_todataset))

data_val2_todataset = get_data(type2_val)
print(len(data_val2_todataset))

data_test1_todataset = get_data(type1_test)
print(len(data_test1_todataset))

data_test2_todataset = get_data(type2_test)
print(len(data_test2_todataset))
# Out:
# 3848
# 563
# 1851
# 561
# 1866

# %%
def read_image(path):
    return torchvision.io.read_image(path)
image = read_image('/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0001.jpg')

# %%
transform = transforms.Compose([transforms.RandomHorizontalFlip(p=0.5),
                                             transforms.RandomVerticalFlip(p=0.5),
                                             transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

# %%
img1 = read_image('/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0001.jpg')
img2 = read_image('/content/drive/MyDrive/DLFAA/Final_Project/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0001.jpg')
concat = torch.cat([img1,img2],dim = 1)
print(concat.shape)
# Out:
# torch.Size([3, 500, 250])

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, data, data_dict, transform):
        self.data = data
        self.data_dict = data_dict
        self.length = len(data)
        self.transform_flag = transform
        self.transform = transforms.Compose([transforms.RandomHorizontalFlip(p=0.5),
                                             transforms.ToPILImage(mode=None),
                                             transforms.RandomApply(transforms=[transforms.RandomEqualize()], p=0.5),
                                             transforms.RandomApply(transforms=[transforms.RandomAutocontrast()], p=0.5),
                                             transforms.RandomApply(transforms=[transforms.RandomAdjustSharpness(sharpness_factor = 2)], p=0.5),
                                             transforms.RandomApply(transforms=[transforms.RandomPosterize(bits=2)], p=0.5),
                                             transforms.RandomApply(transforms=[transforms.RandomRotation(degrees=(15,45))], p=0.5),
                                             transforms.RandomApply(transforms=[transforms.ColorJitter(brightness=.5, hue=.3)], p=0.5),
                                             transforms.ToTensor()
                                             ]) ###is this helpful.   transforms.RandomVerticalFlip(p=0.5)
                                            #  transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))]) # transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
                                             ###add more tranformations
        self.normalize = transforms.Compose([transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

    def __len__(self):
        return len(self.data)
    def __getitem__(self, index):
        #return (self.data[index:index+self.seq_len], self.data[index+1:index+self.seq_len+1])
        #print(len(data))
        anchor = read_image(self.data[index][0])
        anchor = anchor.float()/255
        negative = random.choice(range(self.length))
        while self.data[negative][1] == self.data[index][1]:
            negative = random.choice(range(self.length))
        negative = read_image(self.data[negative][0])
        negative = negative.float()/255

        positive_key = '/'.join(self.data[index][0].split('/')[:-1])
        positive = random.choice(self.data_dict[positive_key])
        positive = read_image(positive_key + '/' + positive)
        positive = positive.float()/255

        if self.transform_flag:
            anchor = self.transform(anchor) ###may try removing transform for anchor and negative and try
            negative = self.transform(negative)
            positive = self.transform(positive)
        anchor = self.normalize(anchor) 
        negative = self.normalize(negative)
        positive = self.normalize(positive)
        pos_example = torch.cat([anchor,positive],dim=1)
        neg_example = torch.cat([anchor,negative],dim=1)
        return torch.stack([pos_example,neg_example],dim=3)

# %%
def collate_fn(data):
    data = torch.stack(data)
    length = data.shape[0]
    data = torch.cat([data[:,:,:,:,0],data[:,:,:,:,1]])
    labels = torch.cat([torch.ones(length),torch.zeros(length)])
    idx = torch.randperm(2*length)
    data = data[idx]
    labels = labels[idx]
    return data,labels

training_data = DataLoader(Dataset(data_train_todataset, train, True),
                           params['batchsize'], 
                           params['shuffle'], 
                           collate_fn =collate_fn, 
                           num_workers=params['num_workers']) #train_ds, BATCH_SIZE, shuffle=True

val1_data = DataLoader(Dataset(data_val1_todataset, type1_val, False), 
                           params['batchsize'], 
                           params['shuffle'], 
                           collate_fn =collate_fn, 
                           num_workers=params['num_workers']) #train_ds, BATCH_SIZE, shuffle=True

val2_data = DataLoader(Dataset(data_val2_todataset, type2_val, False), 
                           params['batchsize'], 
                           params['shuffle'], 
                           collate_fn =collate_fn, 
                           num_workers=params['num_workers']) #train_ds, BATCH_SIZE, shuffle=True
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
"""for data,label in training_data:
    print(data.shape)"""
# Out:
# 'for data,label in training_data:\n    print(data.shape)'

# %%
# model_ft = models.resnet18(pretrained=True)
# num_ftrs = model_ft.fc.in_features
# model_ft.fc = nn.Linear(num_ftrs, 2)
# model_ft = model_ft.to(device)
# criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model_ft.parameters(), params['lr'])
###exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()
        self.features_extract = models.resnet18(pretrained=True)
        self.num_ftrs = self.features_extract.fc.in_features
        #self.features_extract.fc = nn.Linear(self.num_ftrs,1024)
        #self.batch_norm = nn.BatchNorm1d(1024)
        self.features_extract.fc = nn.Sequential(
            nn.Linear(self.num_ftrs,1024),
            nn.ReLU(),
            nn.BatchNorm1d(1024),
            nn.Linear(1024 , 512),
            nn.ReLU(),
            nn.BatchNorm1d(512),
            #nn.Dropout(0.2),
            nn.Linear(512 , 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Linear(256 , 2)
        )
    def forward(self,inputs):
        output = self.features_extract(inputs)
        #features = self.batch_norm(features)
        #output = self.classifier(features)
        return output

# %%
model_ft = model()
model_ft = model_ft.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_ft.parameters(), params['lr'])
print(summary(model_ft,(3,500,250)))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 250, 125]           9,408
#        BatchNorm2d-2         [-1, 64, 250, 125]             128
#               ReLU-3         [-1, 64, 250, 125]               0
#          MaxPool2d-4          [-1, 64, 125, 63]               0
#             Conv2d-5          [-1, 64, 125, 63]          36,864
#        BatchNorm2d-6          [-1, 64, 125, 63]             128
#               ReLU-7          [-1, 64, 125, 63]               0
#             Conv2d-8          [-1, 64, 125, 63]          36,864
#        BatchNorm2d-9          [-1, 64, 125, 63]             128
#              ReLU-10          [-1, 64, 125, 63]               0
#        BasicBlock-11          [-1, 64, 125, 63]               0
#            Conv2d-12          [-1, 64, 125, 63]          36,864
#       BatchNorm2d-13          [-1, 64, 125, 63]             128
#              ReLU-14          [-1, 64, 125, 63]               0
#            Conv2d-15          [-1, 64, 125, 63]          36,864
#       BatchNorm2d-16          [-1, 64, 125, 63]             128
#              ReLU-17          [-1, 64, 125, 63]               0
#        BasicBlock-18          [-1, 64, 125, 63]               0
#            Conv2d-19          [-1, 128, 63, 32]          73,728
#       BatchNorm2d-20          [-1, 128, 63, 32]             256
#              ReLU-21          [-1, 128, 63, 32]               0
#            Conv2d-22          [-1, 128, 63, 32]         147,456
#       BatchNorm2d-23          [-1, 128, 63, 32]             256
#            Conv2d-24          [-1, 128, 63, 32]           8,192
#       BatchNorm2d-25          [-1, 128, 63, 32]             256
#              ReLU-26          [-1, 128, 63, 32]               0
#        BasicBlock-27          [-1, 128, 63, 32]               0
#            Conv2d-28          [-1, 128, 63, 32]         147,456
#       BatchNorm2d-29          [-1, 128, 63, 32]             256
#              ReLU-30          [-1, 128, 63, 32]               0
#            Conv2d-31          [-1, 128, 63, 32]         147,456
#       BatchNorm2d-32          [-1, 128, 63, 32]             256
#              ReLU-33          [-1, 128, 63, 32]               0
#        BasicBlock-34          [-1, 128, 63, 32]               0
#            Conv2d-35          [-1, 256, 32, 16]         294,912
#       BatchNorm2d-36          [-1, 256, 32, 16]             512
#              ReLU-37          [-1, 256, 32, 16]               0
#            Conv2d-38          [-1, 256, 32, 16]         589,824
#       BatchNorm2d-39          [-1, 256, 32, 16]             512
#            Conv2d-40          [-1, 256, 32, 16]          32,768
#       BatchNorm2d-41          [-1, 256, 32, 16]             512
#              ReLU-42          [-1, 256, 32, 16]               0
#        BasicBlock-43          [-1, 256, 32, 16]               0
#            Conv2d-44          [-1, 256, 32, 16]         589,824
#       BatchNorm2d-45          [-1, 256, 32, 16]             512
#              ReLU-46          [-1, 256, 32, 16]               0
#            Conv2d-47          [-1, 256, 32, 16]         589,824
#       BatchNorm2d-48          [-1, 256, 32, 16]             512
#              ReLU-49          [-1, 256, 32, 16]               0
#        BasicBlock-50          [-1, 256, 32, 16]               0
#            Conv2d-51           [-1, 512, 16, 8]       1,179,648
#       BatchNorm2d-52           [-1, 512, 16, 8]           1,024
#              ReLU-53           [-1, 512, 16, 8]               0
#            Conv2d-54           [-1, 512, 16, 8]       2,359,296
#       BatchNorm2d-55           [-1, 512, 16, 8]           1,024
#            Conv2d-56           [-1, 512, 16, 8]         131,072
#       BatchNorm2d-57           [-1, 512, 16, 8]           1,024
#              ReLU-58           [-1, 512, 16, 8]               0
#        BasicBlock-59           [-1, 512, 16, 8]               0
#            Conv2d-60           [-1, 512, 16, 8]       2,359,296
#       BatchNorm2d-61           [-1, 512, 16, 8]           1,024
#              ReLU-62           [-1, 512, 16, 8]               0
#            Conv2d-63           [-1, 512, 16, 8]       2,359,296
#       BatchNorm2d-64           [-1, 512, 16, 8]           1,024
#              ReLU-65           [-1, 512, 16, 8]               0
#        BasicBlock-66           [-1, 512, 16, 8]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                 [-1, 1024]         525,312
#              ReLU-69                 [-1, 1024]               0
#       BatchNorm1d-70                 [-1, 1024]           2,048
#            Linear-71                  [-1, 512]         524,800
#              ReLU-72                  [-1, 512]               0
#       BatchNorm1d-73                  [-1, 512]           1,024
#            Linear-74                  [-1, 256]         131,328
#              ReLU-75                  [-1, 256]               0
#       BatchNorm1d-76                  [-1, 256]             512
#            Linear-77                    [-1, 2]             514
#            ResNet-78                    [-1, 2]               0
# ================================================================
# Total params: 12,362,050
# Trainable params: 12,362,050
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.43
# Forward/backward pass size (MB): 159.00
# Params size (MB): 47.16
# Estimated Total Size (MB): 207.59
# ----------------------------------------------------------------
# None

# %%
f = open('history.txt','w')

# %%
#summary(model_ft,(3,500,250))
torch.cuda.empty_cache()

# %%
for epoch in range(params['epochs']):
    running_loss = 0.0
    batch_count = 0
    correct = 0
    total = 0
    for i, x in enumerate(training_data, 0):
        batch_count += 1
        inputs, labels = x
        labels=labels.type(torch.LongTensor)
        inputs = inputs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        outputs = model_ft(inputs)
        loss = criterion(outputs,labels)

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        print("Epoch", epoch+1, "Batch:", batch_count, "Loss", loss.item(), "accuracy", (predicted == labels).sum().item()/labels.size(0))

        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        train_accuracy = correct / total
        train_loss = running_loss / batch_count
    print('Accuracy of train images: {}'.format( train_accuracy))
    print("E:{}, Train Loss:{}".format(epoch+1, train_loss))

    #validation1
    correct = 0
    total = 0
    val1_loss = 0.0
    batch_count = 0
    with torch.no_grad():
        for data in val1_data:

            batch_count+=1
            images,labels = data
            labels=labels.type(torch.LongTensor)
            images = images.to(device)
            labels = labels.to(device)
            outputs = model_ft(images)  
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
                
            loss = criterion(outputs, labels)       
            val1_loss += loss.item()
    val1_loss /= batch_count
    val1_accuracy = correct/total
    print('Epoch {} Accuracy of val1 images: {}'.format(epoch+1,  val1_accuracy))
    print('Epoch {} Val1 Loss: {}'.format(epoch+1, val1_loss))

    #validation2
    correct = 0
    total = 0
    val2_loss = 0.0
    batch_count = 0
    with torch.no_grad():
        for data in val2_data:

            batch_count+=1
            images, labels = data
            labels = labels.type(torch.LongTensor)
            images = images.to(device)
            labels = labels.to(device)
            outputs = model_ft(images)  
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
                
            loss = criterion(outputs,labels)       
            val2_loss += loss.item()
    val2_loss /= batch_count
    val2_accuracy = correct / total
    print('Epoch {} Accuracy of val2 images: {}'.format(epoch+1, val2_accuracy ))
    print('Epoch {} Val2 Loss: {}'.format(epoch+1, val2_loss))
    f = open('history.txt','a')
    f.write(str(epoch+1)+','+str(train_loss)+','+str(train_accuracy)+','+str(val1_loss)+','+str(val1_accuracy)+','+str(val2_loss)+','+str(val2_accuracy)+'\n')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch 1 Batch: 1 Loss 0.7876631021499634 accuracy 0.46875
# Epoch 1 Batch: 2 Loss 0.727361261844635 accuracy 0.53125
# Epoch 1 Batch: 3 Loss 0.7368002533912659 accuracy 0.53125
# Epoch 1 Batch: 4 Loss 0.7784323692321777 accuracy 0.46875
# Epoch 1 Batch: 5 Loss 0.8132472634315491 accuracy 0.5
# Epoch 1 Batch: 6 Loss 0.7393433451652527 accuracy 0.5625
# Epoch 1 Batch: 7 Loss 0.842289388179779 accuracy 0.4375
# Epoch 1 Batch: 8 Loss 0.8583274483680725 accuracy 0.375
# Epoch 1 Batch: 9 Loss 0.801540195941925 accuracy 0.46875
# Epoch 1 Batch: 10 Loss 0.8273864388465881 accuracy 0.5
# Epoch 1 Batch: 11 Loss 0.7369282245635986 accuracy 0.5
# Epoch 1 Batch: 12 Loss 0.822578489780426 accuracy 0.5
# Epoch 1 Batch: 13 Loss 0.7678515315055847 accuracy 0.5625
# Epoch 1 Batch: 14 Loss 0.8063057065010071 accuracy 0.46875
# Epoch 1 Batch: 15 Loss 0.8107502460479736 accuracy 0.4375
# Epoch 1 Batch: 16 Loss 0.800701379776001 accuracy 0.40625
# Epoch 1 Batch: 17 Loss 0.7946603298187256 accuracy 0.5
# Epoch 1 Batch: 18 Loss 0.9266869425773621 accuracy 0.34375
# Epoch 1 Batch: 19 Loss 0.7327829599380493 accuracy 0.46875
# Epoch 1 Batch: 20 Loss 0.6569026112556458 accuracy 0.65625
# Epoch 1 Batch: 21 Loss 0.7719935178756714 accuracy 0.5
# Epoch 1 Batch: 22 Loss 0.7093949317932129 accuracy 0.5625
# Epoch 1 Batch: 23 Loss 0.7790666222572327 accuracy 0.4375
# Epoch 1 Batch: 24 Loss 0.7084004282951355 accuracy 0.59375
# Epoch 1 Batch: 25 Loss 0.6854425072669983 accuracy 0.6875
# Epoch 1 Batch: 26 Loss 0.8076469898223877 accuracy 0.5
# Epoch 1 Batch: 27 Loss 0.6103346943855286 accuracy 0.75
# Epoch 1 Batch: 28 Loss 0.7467200756072998 accuracy 0.59375
# Epoch 1 Batch: 29 Loss 0.7266666293144226 accuracy 0.5625
# Epoch 1 Batch: 30 Loss 0.7542892694473267 accuracy 0.625
# Epoch 1 Batch: 31 Loss 0.7630842924118042 accuracy 0.53125
# Epoch 1 Batch: 32 Loss 0.7266881465911865 accuracy 0.5625
# Epoch 1 Batch: 33 Loss 0.9300810098648071 accuracy 0.40625
# Epoch 1 Batch: 34 Loss 0.6763768196105957 accuracy 0.625
# Epoch 1 Batch: 35 Loss 0.8318549394607544 accuracy 0.4375
# Epoch 1 Batch: 36 Loss 0.8602116703987122 accuracy 0.40625
# Epoch 1 Batch: 37 Loss 0.7745850086212158 accuracy 0.5
# Epoch 1 Batch: 38 Loss 0.7203887701034546 accuracy 0.5
# Epoch 1 Batch: 39 Loss 0.7441394329071045 accuracy 0.53125
# Epoch 1 Batch: 40 Loss 0.820790708065033 accuracy 0.4375
# Epoch 1 Batch: 41 Loss 0.7195770740509033 accuracy 0.53125
# Epoch 1 Batch: 42 Loss 0.7224497199058533 accuracy 0.5625
# Epoch 1 Batch: 43 Loss 0.7838379740715027 accuracy 0.5
# Epoch 1 Batch: 44 Loss 0.6809262037277222 accuracy 0.5625
# Epoch 1 Batch: 45 Loss 0.9148675203323364 accuracy 0.3125
# Epoch 1 Batch: 46 Loss 0.7323049306869507 accuracy 0.59375
# Epoch 1 Batch: 47 Loss 0.733169674873352 accuracy 0.53125
# Epoch 1 Batch: 48 Loss 0.7699456214904785 accuracy 0.53125
# Epoch 1 Batch: 49 Loss 0.7223575711250305 accuracy 0.59375
# Epoch 1 Batch: 50 Loss 0.7216383218765259 accuracy 0.46875
# Epoch 1 Batch: 51 Loss 0.6893408298492432 accuracy 0.53125
# Epoch 1 Batch: 52 Loss 0.6596354842185974 accuracy 0.5
# Epoch 1 Batch: 53 Loss 0.7582464218139648 accuracy 0.4375
# Epoch 1 Batch: 54 Loss 0.7125843167304993 accuracy 0.40625
# Epoch 1 Batch: 55 Loss 0.6643347144126892 accuracy 0.625
# Epoch 1 Batch: 56 Loss 0.7516927123069763 accuracy 0.46875
# Epoch 1 Batch: 57 Loss 0.7565946578979492 accuracy 0.625
# Epoch 1 Batch: 58 Loss 0.7016215920448303 accuracy 0.59375
# Epoch 1 Batch: 59 Loss 0.7466245293617249 accuracy 0.5
# Epoch 1 Batch: 60 Loss 0.7880848050117493 accuracy 0.46875
# Epoch 1 Batch: 61 Loss 0.7051020264625549 accuracy 0.46875
# Epoch 1 Batch: 62 Loss 0.7591310143470764 accuracy 0.5625
# Epoch 1 Batch: 63 Loss 0.8504171371459961 accuracy 0.34375
# Epoch 1 Batch: 64 Loss 0.7611613273620605 accuracy 0.5625
# Epoch 1 Batch: 65 Loss 0.7215226292610168 accuracy 0.46875
# Epoch 1 Batch: 66 Loss 0.8499648571014404 accuracy 0.375
# Epoch 1 Batch: 67 Loss 0.7661252021789551 accuracy 0.4375
# Epoch 1 Batch: 68 Loss 0.6556180119514465 accuracy 0.5
# Epoch 1 Batch: 69 Loss 0.785986602306366 accuracy 0.4375
# Epoch 1 Batch: 70 Loss 0.7789483666419983 accuracy 0.375
# Epoch 1 Batch: 71 Loss 0.7221440076828003 accuracy 0.53125
# Epoch 1 Batch: 72 Loss 0.7514452338218689 accuracy 0.5625
# Epoch 1 Batch: 73 Loss 0.7231899499893188 accuracy 0.5
# Epoch 1 Batch: 74 Loss 0.6668829321861267 accuracy 0.5
# Epoch 1 Batch: 75 Loss 0.6581723690032959 accuracy 0.625
# Epoch 1 Batch: 76 Loss 0.7894179224967957 accuracy 0.375
# Epoch 1 Batch: 77 Loss 0.7574253678321838 accuracy 0.53125
# Epoch 1 Batch: 78 Loss 0.667425274848938 accuracy 0.65625
# Epoch 1 Batch: 79 Loss 0.7044771909713745 accuracy 0.53125
# Epoch 1 Batch: 80 Loss 0.6553248167037964 accuracy 0.5625
# Epoch 1 Batch: 81 Loss 0.7781229019165039 accuracy 0.4375
# Epoch 1 Batch: 82 Loss 0.7510954141616821 accuracy 0.34375
# Epoch 1 Batch: 83 Loss 0.7761462926864624 accuracy 0.40625
# Epoch 1 Batch: 84 Loss 0.7581281661987305 accuracy 0.46875
# Epoch 1 Batch: 85 Loss 0.6845937371253967 accuracy 0.625
# Epoch 1 Batch: 86 Loss 0.763102114200592 accuracy 0.53125
# Epoch 1 Batch: 87 Loss 0.6969221234321594 accuracy 0.53125
# Epoch 1 Batch: 88 Loss 0.6917006373405457 accuracy 0.53125
# Epoch 1 Batch: 89 Loss 0.6523362398147583 accuracy 0.6875
# Epoch 1 Batch: 90 Loss 0.753090500831604 accuracy 0.5
# Epoch 1 Batch: 91 Loss 0.7615332007408142 accuracy 0.4375
# Epoch 1 Batch: 92 Loss 0.7213807106018066 accuracy 0.46875
# Epoch 1 Batch: 93 Loss 0.8505945801734924 accuracy 0.375
# Epoch 1 Batch: 94 Loss 0.6616120338439941 accuracy 0.5625
# Epoch 1 Batch: 95 Loss 0.7587050795555115 accuracy 0.4375
# Epoch 1 Batch: 96 Loss 0.7215570211410522 accuracy 0.53125
# Epoch 1 Batch: 97 Loss 0.6898363828659058 accuracy 0.59375
# Epoch 1 Batch: 98 Loss 0.6636391878128052 accuracy 0.59375
# Epoch 1 Batch: 99 Loss 0.730911910533905 accuracy 0.5625
# Epoch 1 Batch: 100 Loss 0.6910855174064636 accuracy 0.59375
# Epoch 1 Batch: 101 Loss 0.6592813730239868 accuracy 0.6875
# Epoch 1 Batch: 102 Loss 0.7942305207252502 accuracy 0.375
# Epoch 1 Batch: 103 Loss 0.6477893590927124 accuracy 0.6875
# Epoch 1 Batch: 104 Loss 0.7417833209037781 accuracy 0.46875
# Epoch 1 Batch: 105 Loss 0.7464281320571899 accuracy 0.46875
# Epoch 1 Batch: 106 Loss 0.6667590141296387 accuracy 0.65625
# Epoch 1 Batch: 107 Loss 0.6902374029159546 accuracy 0.5625
# Epoch 1 Batch: 108 Loss 0.7015179395675659 accuracy 0.5625
# Epoch 1 Batch: 109 Loss 0.6394007802009583 accuracy 0.5625
# Epoch 1 Batch: 110 Loss 0.6642727255821228 accuracy 0.5625
# Epoch 1 Batch: 111 Loss 0.6955670118331909 accuracy 0.53125
# Epoch 1 Batch: 112 Loss 0.7665230631828308 accuracy 0.4375
# Epoch 1 Batch: 113 Loss 0.7034282088279724 accuracy 0.53125
# Epoch 1 Batch: 114 Loss 0.7252269387245178 accuracy 0.46875
# Epoch 1 Batch: 115 Loss 0.7723712921142578 accuracy 0.5
# Epoch 1 Batch: 116 Loss 0.6777554154396057 accuracy 0.53125
# Epoch 1 Batch: 117 Loss 0.6493536233901978 accuracy 0.625
# Epoch 1 Batch: 118 Loss 0.6294326782226562 accuracy 0.59375
# Epoch 1 Batch: 119 Loss 0.7031052708625793 accuracy 0.6875
# Epoch 1 Batch: 120 Loss 0.669718861579895 accuracy 0.5
# Epoch 1 Batch: 121 Loss 0.6721765398979187 accuracy 0.625
# Epoch 1 Batch: 122 Loss 0.8158025145530701 accuracy 0.375
# Epoch 1 Batch: 123 Loss 0.6870793104171753 accuracy 0.59375
# Epoch 1 Batch: 124 Loss 0.6360811591148376 accuracy 0.65625
# Epoch 1 Batch: 125 Loss 0.6425203680992126 accuracy 0.5625
# Epoch 1 Batch: 126 Loss 0.6969821453094482 accuracy 0.5
# Epoch 1 Batch: 127 Loss 0.7048115134239197 accuracy 0.5625
# Epoch 1 Batch: 128 Loss 0.5627101063728333 accuracy 0.78125
# Epoch 1 Batch: 129 Loss 0.7318546175956726 accuracy 0.5625
# Epoch 1 Batch: 130 Loss 0.7485543489456177 accuracy 0.5625
# Epoch 1 Batch: 131 Loss 0.7668625116348267 accuracy 0.40625
# Epoch 1 Batch: 132 Loss 0.7278626561164856 accuracy 0.4375
# Epoch 1 Batch: 133 Loss 0.7176318168640137 accuracy 0.5625
# Epoch 1 Batch: 134 Loss 0.7323166728019714 accuracy 0.4375
# Epoch 1 Batch: 135 Loss 0.746501088142395 accuracy 0.53125
# Epoch 1 Batch: 136 Loss 0.7206698060035706 accuracy 0.53125
# Epoch 1 Batch: 137 Loss 0.7148422002792358 accuracy 0.59375
# Epoch 1 Batch: 138 Loss 0.897395670413971 accuracy 0.4375
# Epoch 1 Batch: 139 Loss 0.6555082201957703 accuracy 0.5625
# Epoch 1 Batch: 140 Loss 0.6782709360122681 accuracy 0.6875
# Epoch 1 Batch: 141 Loss 0.7442041635513306 accuracy 0.5
# Epoch 1 Batch: 142 Loss 0.7118270993232727 accuracy 0.65625
# Epoch 1 Batch: 143 Loss 0.6906402707099915 accuracy 0.59375
# Epoch 1 Batch: 144 Loss 0.6708317995071411 accuracy 0.65625
# Epoch 1 Batch: 145 Loss 0.7413952350616455 accuracy 0.5
# Epoch 1 Batch: 146 Loss 0.7230857014656067 accuracy 0.5625
# Epoch 1 Batch: 147 Loss 0.7486372590065002 accuracy 0.5625
# Epoch 1 Batch: 148 Loss 0.6233559846878052 accuracy 0.65625
# Epoch 1 Batch: 149 Loss 0.7524303197860718 accuracy 0.40625
# Epoch 1 Batch: 150 Loss 0.673994243144989 accuracy 0.59375
# Epoch 1 Batch: 151 Loss 0.665032684803009 accuracy 0.5625
# Epoch 1 Batch: 152 Loss 0.7787527441978455 accuracy 0.46875
# Epoch 1 Batch: 153 Loss 0.7715491056442261 accuracy 0.40625
# Epoch 1 Batch: 154 Loss 0.7404677867889404 accuracy 0.53125
# Epoch 1 Batch: 155 Loss 0.6707057952880859 accuracy 0.59375
# Epoch 1 Batch: 156 Loss 0.720456063747406 accuracy 0.5
# Epoch 1 Batch: 157 Loss 0.7673205137252808 accuracy 0.46875
# Epoch 1 Batch: 158 Loss 0.6312013268470764 accuracy 0.65625
# Epoch 1 Batch: 159 Loss 0.7604695558547974 accuracy 0.4375
# Epoch 1 Batch: 160 Loss 0.7209703922271729 accuracy 0.53125
# Epoch 1 Batch: 161 Loss 0.6913169026374817 accuracy 0.625
# Epoch 1 Batch: 162 Loss 0.6344138383865356 accuracy 0.65625
# Epoch 1 Batch: 163 Loss 0.650283694267273 accuracy 0.625
# Epoch 1 Batch: 164 Loss 0.6659810543060303 accuracy 0.6875
# Epoch 1 Batch: 165 Loss 0.6765171885490417 accuracy 0.53125
# Epoch 1 Batch: 166 Loss 0.6766740679740906 accuracy 0.59375
# Epoch 1 Batch: 167 Loss 0.7386889457702637 accuracy 0.5
# Epoch 1 Batch: 168 Loss 0.677708625793457 accuracy 0.625
# Epoch 1 Batch: 169 Loss 0.7238383889198303 accuracy 0.5
# Epoch 1 Batch: 170 Loss 0.6493772268295288 accuracy 0.59375
# Epoch 1 Batch: 171 Loss 0.6787490844726562 accuracy 0.53125
# Epoch 1 Batch: 172 Loss 0.656991720199585 accuracy 0.5625
# Epoch 1 Batch: 173 Loss 0.6968011260032654 accuracy 0.625
# Epoch 1 Batch: 174 Loss 0.6216416954994202 accuracy 0.625
# Epoch 1 Batch: 175 Loss 0.6281454563140869 accuracy 0.6875
# Epoch 1 Batch: 176 Loss 0.6801734566688538 accuracy 0.5625
# Epoch 1 Batch: 177 Loss 0.7213634252548218 accuracy 0.46875
# Epoch 1 Batch: 178 Loss 0.6917341351509094 accuracy 0.59375
# Epoch 1 Batch: 179 Loss 0.5623998641967773 accuracy 0.71875
# Epoch 1 Batch: 180 Loss 0.7316621541976929 accuracy 0.5625
# Epoch 1 Batch: 181 Loss 0.7022499442100525 accuracy 0.53125
# Epoch 1 Batch: 182 Loss 0.7531498670578003 accuracy 0.5
# Epoch 1 Batch: 183 Loss 0.7526106834411621 accuracy 0.59375
# Epoch 1 Batch: 184 Loss 0.6546600461006165 accuracy 0.59375
# Epoch 1 Batch: 185 Loss 0.6882849931716919 accuracy 0.59375
# Epoch 1 Batch: 186 Loss 0.6018600463867188 accuracy 0.65625
# Epoch 1 Batch: 187 Loss 0.6645494699478149 accuracy 0.71875
# Epoch 1 Batch: 188 Loss 0.8417505621910095 accuracy 0.28125
# Epoch 1 Batch: 189 Loss 0.6410460472106934 accuracy 0.65625
# Epoch 1 Batch: 190 Loss 0.6857119202613831 accuracy 0.5625
# Epoch 1 Batch: 191 Loss 0.6450848579406738 accuracy 0.75
# Epoch 1 Batch: 192 Loss 0.6823515892028809 accuracy 0.53125
# Epoch 1 Batch: 193 Loss 0.7974761128425598 accuracy 0.5
# Epoch 1 Batch: 194 Loss 0.781039834022522 accuracy 0.5
# Epoch 1 Batch: 195 Loss 0.6790556907653809 accuracy 0.5625
# Epoch 1 Batch: 196 Loss 0.7532135248184204 accuracy 0.46875
# Epoch 1 Batch: 197 Loss 0.7241265177726746 accuracy 0.5625
# Epoch 1 Batch: 198 Loss 0.6751158237457275 accuracy 0.65625
# Epoch 1 Batch: 199 Loss 0.6806866526603699 accuracy 0.625
# Epoch 1 Batch: 200 Loss 0.7322241067886353 accuracy 0.40625
# Epoch 1 Batch: 201 Loss 0.6912708282470703 accuracy 0.59375
# Epoch 1 Batch: 202 Loss 0.7554147839546204 accuracy 0.53125
# Epoch 1 Batch: 203 Loss 0.7226083278656006 accuracy 0.4375
# Epoch 1 Batch: 204 Loss 0.7545776963233948 accuracy 0.40625
# Epoch 1 Batch: 205 Loss 0.6688586473464966 accuracy 0.59375
# Epoch 1 Batch: 206 Loss 0.6278882622718811 accuracy 0.625
# Epoch 1 Batch: 207 Loss 0.7553924322128296 accuracy 0.40625
# Epoch 1 Batch: 208 Loss 0.6612832546234131 accuracy 0.5625
# Epoch 1 Batch: 209 Loss 0.6549086570739746 accuracy 0.5625
# Epoch 1 Batch: 210 Loss 0.6447141766548157 accuracy 0.53125
# Epoch 1 Batch: 211 Loss 0.7210601568222046 accuracy 0.4375
# Epoch 1 Batch: 212 Loss 0.6104636788368225 accuracy 0.625
# Epoch 1 Batch: 213 Loss 0.7050368785858154 accuracy 0.46875
# Epoch 1 Batch: 214 Loss 0.7031283378601074 accuracy 0.53125
# Epoch 1 Batch: 215 Loss 0.6595885753631592 accuracy 0.625
# Epoch 1 Batch: 216 Loss 0.7036263346672058 accuracy 0.5625
# Epoch 1 Batch: 217 Loss 0.6643203496932983 accuracy 0.59375
# Epoch 1 Batch: 218 Loss 0.745348334312439 accuracy 0.53125
# Epoch 1 Batch: 219 Loss 0.7307843565940857 accuracy 0.46875
# Epoch 1 Batch: 220 Loss 0.7377227544784546 accuracy 0.53125
# Epoch 1 Batch: 221 Loss 0.6411821246147156 accuracy 0.65625
# Epoch 1 Batch: 222 Loss 0.6792148351669312 accuracy 0.59375
# Epoch 1 Batch: 223 Loss 0.7191416025161743 accuracy 0.625
# Epoch 1 Batch: 224 Loss 0.6848734021186829 accuracy 0.59375
# Epoch 1 Batch: 225 Loss 0.6720961332321167 accuracy 0.65625
# Epoch 1 Batch: 226 Loss 0.7599316835403442 accuracy 0.46875
# Epoch 1 Batch: 227 Loss 0.5904518365859985 accuracy 0.71875
# Epoch 1 Batch: 228 Loss 0.6945003271102905 accuracy 0.59375
# Epoch 1 Batch: 229 Loss 0.675183892250061 accuracy 0.46875
# Epoch 1 Batch: 230 Loss 0.7373589873313904 accuracy 0.625
# Epoch 1 Batch: 231 Loss 0.6500166654586792 accuracy 0.5625
# Epoch 1 Batch: 232 Loss 0.7444297075271606 accuracy 0.5
# Epoch 1 Batch: 233 Loss 0.6073591113090515 accuracy 0.5625
# Epoch 1 Batch: 234 Loss 0.5091477036476135 accuracy 0.78125
# Epoch 1 Batch: 235 Loss 0.6897344589233398 accuracy 0.53125
# Epoch 1 Batch: 236 Loss 0.7486187815666199 accuracy 0.53125
# Epoch 1 Batch: 237 Loss 0.724739670753479 accuracy 0.59375
# Epoch 1 Batch: 238 Loss 0.5024780035018921 accuracy 0.78125
# Epoch 1 Batch: 239 Loss 0.7499724626541138 accuracy 0.59375
# Epoch 1 Batch: 240 Loss 0.6607193350791931 accuracy 0.59375
# Epoch 1 Batch: 241 Loss 0.7624596357345581 accuracy 0.5
# Accuracy of train images: 0.5395010395010394
# E:1, Train Loss:0.7184762212745381
# Epoch 1 Accuracy of val1 images: 0.6669626998223801
# Epoch 1 Val1 Loss: 0.6178673903147379
# Epoch 1 Accuracy of val2 images: 0.6545110750945435
# Epoch 1 Val2 Loss: 0.6200320152886982
# Epoch 2 Batch: 1 Loss 0.6564815044403076 accuracy 0.53125
# Epoch 2 Batch: 2 Loss 0.7003756761550903 accuracy 0.5625
# Epoch 2 Batch: 3 Loss 0.5879987478256226 accuracy 0.6875
# Epoch 2 Batch: 4 Loss 0.6253619194030762 accuracy 0.65625
# Epoch 2 Batch: 5 Loss 0.7398500442504883 accuracy 0.46875
# Epoch 2 Batch: 6 Loss 0.6682223677635193 accuracy 0.5625
# Epoch 2 Batch: 7 Loss 0.7394077777862549 accuracy 0.53125
# Epoch 2 Batch: 8 Loss 0.6533202528953552 accuracy 0.625
# Epoch 2 Batch: 9 Loss 0.7049179673194885 accuracy 0.5625
# Epoch 2 Batch: 10 Loss 0.6531252264976501 accuracy 0.59375
# Epoch 2 Batch: 11 Loss 0.691006064414978 accuracy 0.5625
# Epoch 2 Batch: 12 Loss 0.7142829895019531 accuracy 0.59375
# Epoch 2 Batch: 13 Loss 0.794317364692688 accuracy 0.4375
# Epoch 2 Batch: 14 Loss 0.645744800567627 accuracy 0.6875
# Epoch 2 Batch: 15 Loss 0.6870129108428955 accuracy 0.625
# Epoch 2 Batch: 16 Loss 0.6080812215805054 accuracy 0.625
# Epoch 2 Batch: 17 Loss 0.6186805963516235 accuracy 0.59375
# Epoch 2 Batch: 18 Loss 0.768088161945343 accuracy 0.5625
# Epoch 2 Batch: 19 Loss 0.5708679556846619 accuracy 0.75
# Epoch 2 Batch: 20 Loss 0.7550904154777527 accuracy 0.5625
# Epoch 2 Batch: 21 Loss 0.6515870690345764 accuracy 0.5625
# Epoch 2 Batch: 22 Loss 0.6772757172584534 accuracy 0.625
# Epoch 2 Batch: 23 Loss 0.7386496067047119 accuracy 0.46875
# Epoch 2 Batch: 24 Loss 0.6558029651641846 accuracy 0.59375
# Epoch 2 Batch: 25 Loss 0.6213779449462891 accuracy 0.65625
# Epoch 2 Batch: 26 Loss 0.6815943717956543 accuracy 0.5
# Epoch 2 Batch: 27 Loss 0.7117130756378174 accuracy 0.5625
# Epoch 2 Batch: 28 Loss 0.6862292289733887 accuracy 0.5625
# Epoch 2 Batch: 29 Loss 0.7347862720489502 accuracy 0.5625
# Epoch 2 Batch: 30 Loss 0.6363105773925781 accuracy 0.59375
# Epoch 2 Batch: 31 Loss 0.7100339531898499 accuracy 0.59375
# Epoch 2 Batch: 32 Loss 0.760598361492157 accuracy 0.4375
# Epoch 2 Batch: 33 Loss 0.6275315284729004 accuracy 0.65625
# Epoch 2 Batch: 34 Loss 0.7039619088172913 accuracy 0.46875
# Epoch 2 Batch: 35 Loss 0.6529717445373535 accuracy 0.625
# Epoch 2 Batch: 36 Loss 0.6179010272026062 accuracy 0.625
# Epoch 2 Batch: 37 Loss 0.580169141292572 accuracy 0.6875
# Epoch 2 Batch: 38 Loss 0.6072621941566467 accuracy 0.75
# Epoch 2 Batch: 39 Loss 0.7147867679595947 accuracy 0.5625
# Epoch 2 Batch: 40 Loss 0.7040866613388062 accuracy 0.5625
# Epoch 2 Batch: 41 Loss 0.6594281196594238 accuracy 0.6875
# Epoch 2 Batch: 42 Loss 0.6745275259017944 accuracy 0.53125
# Epoch 2 Batch: 43 Loss 0.6954904794692993 accuracy 0.53125
# Epoch 2 Batch: 44 Loss 0.7142423391342163 accuracy 0.625
# Epoch 2 Batch: 45 Loss 0.7170673608779907 accuracy 0.5625
# Epoch 2 Batch: 46 Loss 0.6125940680503845 accuracy 0.6875
# Epoch 2 Batch: 47 Loss 0.59645676612854 accuracy 0.65625
# Epoch 2 Batch: 48 Loss 0.7196266055107117 accuracy 0.5625
# Epoch 2 Batch: 49 Loss 0.5518368482589722 accuracy 0.71875
# Epoch 2 Batch: 50 Loss 0.6092782020568848 accuracy 0.59375
# Epoch 2 Batch: 51 Loss 0.7109623551368713 accuracy 0.5
# Epoch 2 Batch: 52 Loss 0.6778361797332764 accuracy 0.53125
# Epoch 2 Batch: 53 Loss 0.726205587387085 accuracy 0.59375
# Epoch 2 Batch: 54 Loss 0.7064437866210938 accuracy 0.53125
# Epoch 2 Batch: 55 Loss 0.6665167212486267 accuracy 0.53125
# Epoch 2 Batch: 56 Loss 0.6600527167320251 accuracy 0.625
# Epoch 2 Batch: 57 Loss 0.6449874043464661 accuracy 0.59375
# Epoch 2 Batch: 58 Loss 0.60027015209198 accuracy 0.625
# Epoch 2 Batch: 59 Loss 0.6680002808570862 accuracy 0.625
# Epoch 2 Batch: 60 Loss 0.634076714515686 accuracy 0.625
# Epoch 2 Batch: 61 Loss 0.6046949625015259 accuracy 0.6875
# Epoch 2 Batch: 62 Loss 0.6232858300209045 accuracy 0.625
# Epoch 2 Batch: 63 Loss 0.5485610365867615 accuracy 0.71875
# Epoch 2 Batch: 64 Loss 0.7032808661460876 accuracy 0.53125
# Epoch 2 Batch: 65 Loss 0.6859662532806396 accuracy 0.5625
# Epoch 2 Batch: 66 Loss 0.686129629611969 accuracy 0.59375
# Epoch 2 Batch: 67 Loss 0.6188769340515137 accuracy 0.625
# Epoch 2 Batch: 68 Loss 0.69318026304245 accuracy 0.53125
# Epoch 2 Batch: 69 Loss 0.6302646398544312 accuracy 0.65625
# Epoch 2 Batch: 70 Loss 0.6770598292350769 accuracy 0.625
# Epoch 2 Batch: 71 Loss 0.6735569834709167 accuracy 0.5
# Epoch 2 Batch: 72 Loss 0.6264358758926392 accuracy 0.6875
# Epoch 2 Batch: 73 Loss 0.6028740406036377 accuracy 0.6875
# Epoch 2 Batch: 74 Loss 0.735054612159729 accuracy 0.40625
# Epoch 2 Batch: 75 Loss 0.7786008715629578 accuracy 0.4375
# Epoch 2 Batch: 76 Loss 0.6835938096046448 accuracy 0.6875
# Epoch 2 Batch: 77 Loss 0.7163724899291992 accuracy 0.6875
# Epoch 2 Batch: 78 Loss 0.6388859748840332 accuracy 0.6875
# Epoch 2 Batch: 79 Loss 0.6176411509513855 accuracy 0.71875
# Epoch 2 Batch: 80 Loss 0.7206926345825195 accuracy 0.53125
# Epoch 2 Batch: 81 Loss 0.6886945962905884 accuracy 0.65625
# Epoch 2 Batch: 82 Loss 0.6458150148391724 accuracy 0.59375
# Epoch 2 Batch: 83 Loss 0.6633602976799011 accuracy 0.5625
# Epoch 2 Batch: 84 Loss 0.5883773565292358 accuracy 0.65625
# Epoch 2 Batch: 85 Loss 0.6778324842453003 accuracy 0.5625
# Epoch 2 Batch: 86 Loss 0.676092803478241 accuracy 0.65625
# Epoch 2 Batch: 87 Loss 0.5731639266014099 accuracy 0.6875
# Epoch 2 Batch: 88 Loss 0.775976300239563 accuracy 0.46875
# Epoch 2 Batch: 89 Loss 0.7215878367424011 accuracy 0.5625
# Epoch 2 Batch: 90 Loss 0.5539854764938354 accuracy 0.71875
# Epoch 2 Batch: 91 Loss 0.5366773009300232 accuracy 0.71875
# Epoch 2 Batch: 92 Loss 0.6557093262672424 accuracy 0.625
# Epoch 2 Batch: 93 Loss 0.6517065167427063 accuracy 0.71875
# Epoch 2 Batch: 94 Loss 0.6253662705421448 accuracy 0.5625
# Epoch 2 Batch: 95 Loss 0.7417746782302856 accuracy 0.46875
# Epoch 2 Batch: 96 Loss 0.7642790675163269 accuracy 0.5
# Epoch 2 Batch: 97 Loss 0.6553400158882141 accuracy 0.53125
# Epoch 2 Batch: 98 Loss 0.6629785299301147 accuracy 0.53125
# Epoch 2 Batch: 99 Loss 0.6992632746696472 accuracy 0.5625
# Epoch 2 Batch: 100 Loss 0.5305560231208801 accuracy 0.8125
# Epoch 2 Batch: 101 Loss 0.5563533902168274 accuracy 0.625
# Epoch 2 Batch: 102 Loss 0.6081110239028931 accuracy 0.6875
# Epoch 2 Batch: 103 Loss 0.6320337057113647 accuracy 0.65625
# Epoch 2 Batch: 104 Loss 0.7124896049499512 accuracy 0.53125
# Epoch 2 Batch: 105 Loss 0.7923577427864075 accuracy 0.46875
# Epoch 2 Batch: 106 Loss 0.7304621338844299 accuracy 0.53125
# Epoch 2 Batch: 107 Loss 0.6339250206947327 accuracy 0.65625
# Epoch 2 Batch: 108 Loss 0.6725788116455078 accuracy 0.5625
# Epoch 2 Batch: 109 Loss 0.6508421301841736 accuracy 0.53125
# Epoch 2 Batch: 110 Loss 0.6281777024269104 accuracy 0.65625
# Epoch 2 Batch: 111 Loss 0.6624081134796143 accuracy 0.46875
# Epoch 2 Batch: 112 Loss 0.6350076198577881 accuracy 0.65625
# Epoch 2 Batch: 113 Loss 0.7332552671432495 accuracy 0.53125
# Epoch 2 Batch: 114 Loss 0.6634134650230408 accuracy 0.53125
# Epoch 2 Batch: 115 Loss 0.5727740526199341 accuracy 0.71875
# Epoch 2 Batch: 116 Loss 0.6725857853889465 accuracy 0.53125
# Epoch 2 Batch: 117 Loss 0.5073285698890686 accuracy 0.71875
# Epoch 2 Batch: 118 Loss 0.5753275156021118 accuracy 0.65625
# Epoch 2 Batch: 119 Loss 0.6335416436195374 accuracy 0.5625
# Epoch 2 Batch: 120 Loss 0.5981588363647461 accuracy 0.65625
# Epoch 2 Batch: 121 Loss 0.6244834661483765 accuracy 0.625
# Epoch 2 Batch: 122 Loss 0.6584548354148865 accuracy 0.59375
# Epoch 2 Batch: 123 Loss 0.6178131103515625 accuracy 0.65625
# Epoch 2 Batch: 124 Loss 0.622920036315918 accuracy 0.6875
# Epoch 2 Batch: 125 Loss 0.6229175329208374 accuracy 0.71875
# Epoch 2 Batch: 126 Loss 0.811962902545929 accuracy 0.4375
# Epoch 2 Batch: 127 Loss 0.6383347511291504 accuracy 0.65625
# Epoch 2 Batch: 128 Loss 0.6337730884552002 accuracy 0.6875
# Epoch 2 Batch: 129 Loss 0.6050889492034912 accuracy 0.65625
# Epoch 2 Batch: 130 Loss 0.704001784324646 accuracy 0.59375
# Epoch 2 Batch: 131 Loss 0.571804404258728 accuracy 0.75
# Epoch 2 Batch: 132 Loss 0.7002856135368347 accuracy 0.5625
# Epoch 2 Batch: 133 Loss 0.5998803377151489 accuracy 0.65625
# Epoch 2 Batch: 134 Loss 0.7522709369659424 accuracy 0.53125
# Epoch 2 Batch: 135 Loss 0.5711434483528137 accuracy 0.6875
# Epoch 2 Batch: 136 Loss 0.6354891657829285 accuracy 0.59375
# Epoch 2 Batch: 137 Loss 0.7388805747032166 accuracy 0.5625
# Epoch 2 Batch: 138 Loss 0.5816969275474548 accuracy 0.65625
# Epoch 2 Batch: 139 Loss 0.7031648755073547 accuracy 0.5625
# Epoch 2 Batch: 140 Loss 0.599016010761261 accuracy 0.71875
# Epoch 2 Batch: 141 Loss 0.5809112787246704 accuracy 0.65625
# Epoch 2 Batch: 142 Loss 0.6202096939086914 accuracy 0.625
# Epoch 2 Batch: 143 Loss 0.5857868790626526 accuracy 0.6875
# Epoch 2 Batch: 144 Loss 0.6455946564674377 accuracy 0.6875
# Epoch 2 Batch: 145 Loss 0.6398298740386963 accuracy 0.53125
# Epoch 2 Batch: 146 Loss 0.676337480545044 accuracy 0.5625
# Epoch 2 Batch: 147 Loss 0.532666802406311 accuracy 0.71875
# Epoch 2 Batch: 148 Loss 0.6475840210914612 accuracy 0.625
# Epoch 2 Batch: 149 Loss 0.6076536774635315 accuracy 0.65625
# Epoch 2 Batch: 150 Loss 0.7252229452133179 accuracy 0.53125
# Epoch 2 Batch: 151 Loss 0.5366469621658325 accuracy 0.6875
# Epoch 2 Batch: 152 Loss 0.5826892256736755 accuracy 0.6875
# Epoch 2 Batch: 153 Loss 0.6385113000869751 accuracy 0.625
# Epoch 2 Batch: 154 Loss 0.6453256607055664 accuracy 0.65625
# Epoch 2 Batch: 155 Loss 0.6806169152259827 accuracy 0.625
# Epoch 2 Batch: 156 Loss 0.7278590202331543 accuracy 0.5
# Epoch 2 Batch: 157 Loss 0.6751072406768799 accuracy 0.53125
# Epoch 2 Batch: 158 Loss 0.6200113296508789 accuracy 0.75
# Epoch 2 Batch: 159 Loss 0.6014487147331238 accuracy 0.5625
# Epoch 2 Batch: 160 Loss 0.7256842851638794 accuracy 0.5625
# Epoch 2 Batch: 161 Loss 0.7015846371650696 accuracy 0.625
# Epoch 2 Batch: 162 Loss 0.6542522311210632 accuracy 0.6875
# Epoch 2 Batch: 163 Loss 0.5287541151046753 accuracy 0.6875
# Epoch 2 Batch: 164 Loss 0.6636232733726501 accuracy 0.53125
# Epoch 2 Batch: 165 Loss 0.4872543215751648 accuracy 0.78125
# Epoch 2 Batch: 166 Loss 0.6901940703392029 accuracy 0.53125
# Epoch 2 Batch: 167 Loss 0.49424195289611816 accuracy 0.8125
# Epoch 2 Batch: 168 Loss 0.6744224429130554 accuracy 0.46875
# Epoch 2 Batch: 169 Loss 0.5493919253349304 accuracy 0.75
# Epoch 2 Batch: 170 Loss 0.5953636765480042 accuracy 0.6875
# Epoch 2 Batch: 171 Loss 0.6799328327178955 accuracy 0.53125
# Epoch 2 Batch: 172 Loss 0.7508320212364197 accuracy 0.46875
# Epoch 2 Batch: 173 Loss 0.6407631039619446 accuracy 0.625
# Epoch 2 Batch: 174 Loss 0.7866893410682678 accuracy 0.53125
# Epoch 2 Batch: 175 Loss 0.6375414133071899 accuracy 0.6875
# Epoch 2 Batch: 176 Loss 0.7069305777549744 accuracy 0.53125
# Epoch 2 Batch: 177 Loss 0.5901931524276733 accuracy 0.75
# Epoch 2 Batch: 178 Loss 0.6040174961090088 accuracy 0.6875
# Epoch 2 Batch: 179 Loss 0.6237586140632629 accuracy 0.625
# Epoch 2 Batch: 180 Loss 0.6636156439781189 accuracy 0.6875
# Epoch 2 Batch: 181 Loss 0.6461347937583923 accuracy 0.5625
# Epoch 2 Batch: 182 Loss 0.5608621835708618 accuracy 0.65625
# Epoch 2 Batch: 183 Loss 0.6526792645454407 accuracy 0.53125
# Epoch 2 Batch: 184 Loss 0.7643250226974487 accuracy 0.53125
# Epoch 2 Batch: 185 Loss 0.6876298785209656 accuracy 0.5625
# Epoch 2 Batch: 186 Loss 0.6500802636146545 accuracy 0.65625
# Epoch 2 Batch: 187 Loss 0.5820233225822449 accuracy 0.71875
# Epoch 2 Batch: 188 Loss 0.6169757843017578 accuracy 0.59375
# Epoch 2 Batch: 189 Loss 0.6436137557029724 accuracy 0.53125
# Epoch 2 Batch: 190 Loss 0.541800320148468 accuracy 0.8125
# Epoch 2 Batch: 191 Loss 0.6593408584594727 accuracy 0.5
# Epoch 2 Batch: 192 Loss 0.6717749238014221 accuracy 0.59375
# Epoch 2 Batch: 193 Loss 0.7415462136268616 accuracy 0.5
# Epoch 2 Batch: 194 Loss 0.5455722808837891 accuracy 0.71875
# Epoch 2 Batch: 195 Loss 0.666193962097168 accuracy 0.625
# Epoch 2 Batch: 196 Loss 0.6058855652809143 accuracy 0.65625
# Epoch 2 Batch: 197 Loss 0.6372051239013672 accuracy 0.65625
# Epoch 2 Batch: 198 Loss 0.6507979035377502 accuracy 0.65625
# Epoch 2 Batch: 199 Loss 0.568195641040802 accuracy 0.6875
# Epoch 2 Batch: 200 Loss 0.7590528726577759 accuracy 0.625
# Epoch 2 Batch: 201 Loss 0.7222225069999695 accuracy 0.53125
# Epoch 2 Batch: 202 Loss 0.6631587743759155 accuracy 0.625
# Epoch 2 Batch: 203 Loss 0.6297965049743652 accuracy 0.6875
# Epoch 2 Batch: 204 Loss 0.6088939905166626 accuracy 0.65625
# Epoch 2 Batch: 205 Loss 0.6191759705543518 accuracy 0.53125
# Epoch 2 Batch: 206 Loss 0.5564183592796326 accuracy 0.6875
# Epoch 2 Batch: 207 Loss 0.6531718373298645 accuracy 0.65625
# Epoch 2 Batch: 208 Loss 0.6177879571914673 accuracy 0.625
# Epoch 2 Batch: 209 Loss 0.594319224357605 accuracy 0.625
# Epoch 2 Batch: 210 Loss 0.7807002067565918 accuracy 0.46875
# Epoch 2 Batch: 211 Loss 0.623681366443634 accuracy 0.59375
# Epoch 2 Batch: 212 Loss 0.6126238107681274 accuracy 0.71875
# Epoch 2 Batch: 213 Loss 0.6256242394447327 accuracy 0.625
# Epoch 2 Batch: 214 Loss 0.6952848434448242 accuracy 0.59375
# Epoch 2 Batch: 215 Loss 0.5094640254974365 accuracy 0.75
# Epoch 2 Batch: 216 Loss 0.4914637506008148 accuracy 0.78125
# Epoch 2 Batch: 217 Loss 0.6792542338371277 accuracy 0.59375
# Epoch 2 Batch: 218 Loss 0.701195478439331 accuracy 0.5625
# Epoch 2 Batch: 219 Loss 0.5787554979324341 accuracy 0.65625
# Epoch 2 Batch: 220 Loss 0.6885858774185181 accuracy 0.5625
# Epoch 2 Batch: 221 Loss 0.6187107563018799 accuracy 0.59375
# Epoch 2 Batch: 222 Loss 0.6260726451873779 accuracy 0.65625
# Epoch 2 Batch: 223 Loss 0.5935350060462952 accuracy 0.71875
# Epoch 2 Batch: 224 Loss 0.6727518439292908 accuracy 0.53125
# Epoch 2 Batch: 225 Loss 0.7301486730575562 accuracy 0.59375
# Epoch 2 Batch: 226 Loss 0.5691455602645874 accuracy 0.65625
# Epoch 2 Batch: 227 Loss 0.6307248473167419 accuracy 0.65625
# Epoch 2 Batch: 228 Loss 0.528281569480896 accuracy 0.78125
# Epoch 2 Batch: 229 Loss 0.5389819741249084 accuracy 0.71875
# Epoch 2 Batch: 230 Loss 0.6017909049987793 accuracy 0.65625
# Epoch 2 Batch: 231 Loss 0.5396904349327087 accuracy 0.6875
# Epoch 2 Batch: 232 Loss 0.6925874948501587 accuracy 0.59375
# Epoch 2 Batch: 233 Loss 0.589385449886322 accuracy 0.625
# Epoch 2 Batch: 234 Loss 0.5126253962516785 accuracy 0.78125
# Epoch 2 Batch: 235 Loss 0.750370979309082 accuracy 0.5
# Epoch 2 Batch: 236 Loss 0.5783128142356873 accuracy 0.75
# Epoch 2 Batch: 237 Loss 0.48942288756370544 accuracy 0.875
# Epoch 2 Batch: 238 Loss 0.6582729816436768 accuracy 0.5625
# Epoch 2 Batch: 239 Loss 0.5935552716255188 accuracy 0.75
# Epoch 2 Batch: 240 Loss 0.5630189180374146 accuracy 0.59375
# Epoch 2 Batch: 241 Loss 0.7112592458724976 accuracy 0.5625
# Accuracy of train images: 0.6148648648648649
# E:2, Train Loss:0.648264704650863
# Epoch 2 Accuracy of val1 images: 0.7460035523978685
# Epoch 2 Val1 Loss: 0.512712971203857
# Epoch 2 Accuracy of val2 images: 0.7520259319286872
# Epoch 2 Val2 Loss: 0.5053692768360006
# Epoch 3 Batch: 1 Loss 0.6090403199195862 accuracy 0.625
# Epoch 3 Batch: 2 Loss 0.47404366731643677 accuracy 0.84375
# Epoch 3 Batch: 3 Loss 0.5792781710624695 accuracy 0.6875
# Epoch 3 Batch: 4 Loss 0.6260203719139099 accuracy 0.59375
# Epoch 3 Batch: 5 Loss 0.6338217854499817 accuracy 0.59375
# Epoch 3 Batch: 6 Loss 0.5476521253585815 accuracy 0.6875
# Epoch 3 Batch: 7 Loss 0.5954283475875854 accuracy 0.5625
# Epoch 3 Batch: 8 Loss 0.5561732649803162 accuracy 0.71875
# Epoch 3 Batch: 9 Loss 0.5317380428314209 accuracy 0.65625
# Epoch 3 Batch: 10 Loss 0.49310603737831116 accuracy 0.75
# Epoch 3 Batch: 11 Loss 0.6313860416412354 accuracy 0.53125
# Epoch 3 Batch: 12 Loss 0.7266650795936584 accuracy 0.4375
# Epoch 3 Batch: 13 Loss 0.5933120846748352 accuracy 0.78125
# Epoch 3 Batch: 14 Loss 0.5826001763343811 accuracy 0.625
# Epoch 3 Batch: 15 Loss 0.6992706656455994 accuracy 0.625
# Epoch 3 Batch: 16 Loss 0.576686441898346 accuracy 0.625
# Epoch 3 Batch: 17 Loss 0.49342814087867737 accuracy 0.8125
# Epoch 3 Batch: 18 Loss 0.5679032802581787 accuracy 0.625
# Epoch 3 Batch: 19 Loss 0.5243719220161438 accuracy 0.59375
# Epoch 3 Batch: 20 Loss 0.6700122356414795 accuracy 0.5625
# Epoch 3 Batch: 21 Loss 0.52557373046875 accuracy 0.75
# Epoch 3 Batch: 22 Loss 0.5691545009613037 accuracy 0.6875
# Epoch 3 Batch: 23 Loss 0.5609791874885559 accuracy 0.6875
# Epoch 3 Batch: 24 Loss 0.5764189958572388 accuracy 0.65625
# Epoch 3 Batch: 25 Loss 0.6113858222961426 accuracy 0.71875
# Epoch 3 Batch: 26 Loss 0.6618964076042175 accuracy 0.625
# Epoch 3 Batch: 27 Loss 0.6118656992912292 accuracy 0.65625
# Epoch 3 Batch: 28 Loss 0.61308354139328 accuracy 0.65625
# Epoch 3 Batch: 29 Loss 0.5691361427307129 accuracy 0.625
# Epoch 3 Batch: 30 Loss 0.5220380425453186 accuracy 0.75
# Epoch 3 Batch: 31 Loss 0.5402386784553528 accuracy 0.71875
# Epoch 3 Batch: 32 Loss 0.592311441898346 accuracy 0.75
# Epoch 3 Batch: 33 Loss 0.5641448497772217 accuracy 0.75
# Epoch 3 Batch: 34 Loss 0.6289077997207642 accuracy 0.65625
# Epoch 3 Batch: 35 Loss 0.5063232779502869 accuracy 0.6875
# Epoch 3 Batch: 36 Loss 0.539567768573761 accuracy 0.71875
# Epoch 3 Batch: 37 Loss 0.6606468558311462 accuracy 0.5625
# Epoch 3 Batch: 38 Loss 0.4749225974082947 accuracy 0.78125
# Epoch 3 Batch: 39 Loss 0.4700149595737457 accuracy 0.75
# Epoch 3 Batch: 40 Loss 0.581761360168457 accuracy 0.65625
# Epoch 3 Batch: 41 Loss 0.578902542591095 accuracy 0.59375
# Epoch 3 Batch: 42 Loss 0.5353306531906128 accuracy 0.71875
# Epoch 3 Batch: 43 Loss 0.5362644791603088 accuracy 0.75
# Epoch 3 Batch: 44 Loss 0.567326009273529 accuracy 0.625
# Epoch 3 Batch: 45 Loss 0.510650634765625 accuracy 0.75
# Epoch 3 Batch: 46 Loss 0.7404641509056091 accuracy 0.59375
# Epoch 3 Batch: 47 Loss 0.6349577307701111 accuracy 0.65625
# Epoch 3 Batch: 48 Loss 0.5787111520767212 accuracy 0.6875
# Epoch 3 Batch: 49 Loss 0.6149916052818298 accuracy 0.71875
# Epoch 3 Batch: 50 Loss 0.7355153560638428 accuracy 0.5625
# Epoch 3 Batch: 51 Loss 0.6382297277450562 accuracy 0.6875
# Epoch 3 Batch: 52 Loss 0.6416468620300293 accuracy 0.625
# Epoch 3 Batch: 53 Loss 0.4782745838165283 accuracy 0.75
# Epoch 3 Batch: 54 Loss 0.7199837565422058 accuracy 0.5625
# Epoch 3 Batch: 55 Loss 0.5422092080116272 accuracy 0.6875
# Epoch 3 Batch: 56 Loss 0.6144717931747437 accuracy 0.625
# Epoch 3 Batch: 57 Loss 0.6789345145225525 accuracy 0.625
# Epoch 3 Batch: 58 Loss 0.5381051898002625 accuracy 0.71875
# Epoch 3 Batch: 59 Loss 0.702007532119751 accuracy 0.65625
# Epoch 3 Batch: 60 Loss 0.6240426898002625 accuracy 0.65625
# Epoch 3 Batch: 61 Loss 0.6231880784034729 accuracy 0.65625
# Epoch 3 Batch: 62 Loss 0.46129322052001953 accuracy 0.78125
# Epoch 3 Batch: 63 Loss 0.5946372747421265 accuracy 0.71875
# Epoch 3 Batch: 64 Loss 0.6506672501564026 accuracy 0.5625
# Epoch 3 Batch: 65 Loss 0.6027855277061462 accuracy 0.625
# Epoch 3 Batch: 66 Loss 0.47669607400894165 accuracy 0.71875
# Epoch 3 Batch: 67 Loss 0.5863782167434692 accuracy 0.71875
# Epoch 3 Batch: 68 Loss 0.5490406155586243 accuracy 0.6875
# Epoch 3 Batch: 69 Loss 0.5868114829063416 accuracy 0.6875
# Epoch 3 Batch: 70 Loss 0.8043381571769714 accuracy 0.53125
# Epoch 3 Batch: 71 Loss 0.646381676197052 accuracy 0.59375
# Epoch 3 Batch: 72 Loss 0.8099590539932251 accuracy 0.5625
# Epoch 3 Batch: 73 Loss 0.5023372769355774 accuracy 0.78125
# Epoch 3 Batch: 74 Loss 0.44141077995300293 accuracy 0.78125
# Epoch 3 Batch: 75 Loss 0.56319659948349 accuracy 0.625
# Epoch 3 Batch: 76 Loss 0.5028970837593079 accuracy 0.6875
# Epoch 3 Batch: 77 Loss 0.5317206978797913 accuracy 0.71875
# Epoch 3 Batch: 78 Loss 0.6913926005363464 accuracy 0.5625
# Epoch 3 Batch: 79 Loss 0.5775896310806274 accuracy 0.6875
# Epoch 3 Batch: 80 Loss 0.4892142415046692 accuracy 0.78125
# Epoch 3 Batch: 81 Loss 0.4611572027206421 accuracy 0.78125
# Epoch 3 Batch: 82 Loss 0.5709194540977478 accuracy 0.65625
# Epoch 3 Batch: 83 Loss 0.5345238447189331 accuracy 0.65625
# Epoch 3 Batch: 84 Loss 0.565657913684845 accuracy 0.71875
# Epoch 3 Batch: 85 Loss 0.541458249092102 accuracy 0.71875
# Epoch 3 Batch: 86 Loss 0.606382429599762 accuracy 0.59375
# Epoch 3 Batch: 87 Loss 0.6346510052680969 accuracy 0.59375
# Epoch 3 Batch: 88 Loss 0.594930112361908 accuracy 0.59375
# Epoch 3 Batch: 89 Loss 0.5058557987213135 accuracy 0.75
# Epoch 3 Batch: 90 Loss 0.46367764472961426 accuracy 0.8125
# Epoch 3 Batch: 91 Loss 0.477212518453598 accuracy 0.71875
# Epoch 3 Batch: 92 Loss 0.5361058712005615 accuracy 0.71875
# Epoch 3 Batch: 93 Loss 0.6078305840492249 accuracy 0.65625
# Epoch 3 Batch: 94 Loss 0.540838897228241 accuracy 0.65625
# Epoch 3 Batch: 95 Loss 0.641508936882019 accuracy 0.625
# Epoch 3 Batch: 96 Loss 0.5881404280662537 accuracy 0.6875
# Epoch 3 Batch: 97 Loss 0.4836524724960327 accuracy 0.6875
# Epoch 3 Batch: 98 Loss 0.5533416867256165 accuracy 0.71875
# Epoch 3 Batch: 99 Loss 0.6689159870147705 accuracy 0.625
# Epoch 3 Batch: 100 Loss 0.5885423421859741 accuracy 0.6875
# Epoch 3 Batch: 101 Loss 0.5160763263702393 accuracy 0.6875
# Epoch 3 Batch: 102 Loss 0.5116974115371704 accuracy 0.6875
# Epoch 3 Batch: 103 Loss 0.5065444707870483 accuracy 0.75
# Epoch 3 Batch: 104 Loss 0.554601788520813 accuracy 0.65625
# Epoch 3 Batch: 105 Loss 0.5765011310577393 accuracy 0.71875
# Epoch 3 Batch: 106 Loss 0.6161447167396545 accuracy 0.6875
# Epoch 3 Batch: 107 Loss 0.5907964706420898 accuracy 0.625
# Epoch 3 Batch: 108 Loss 0.42777255177497864 accuracy 0.8125
# Epoch 3 Batch: 109 Loss 0.5443567037582397 accuracy 0.6875
# Epoch 3 Batch: 110 Loss 0.5953625440597534 accuracy 0.65625
# Epoch 3 Batch: 111 Loss 0.5263872742652893 accuracy 0.65625
# Epoch 3 Batch: 112 Loss 0.5489289164543152 accuracy 0.78125
# Epoch 3 Batch: 113 Loss 0.530030369758606 accuracy 0.75
# Epoch 3 Batch: 114 Loss 0.5451723337173462 accuracy 0.625
# Epoch 3 Batch: 115 Loss 0.49913886189460754 accuracy 0.75
# Epoch 3 Batch: 116 Loss 0.6785985231399536 accuracy 0.5625
# Epoch 3 Batch: 117 Loss 0.5104642510414124 accuracy 0.78125
# Epoch 3 Batch: 118 Loss 0.4172688126564026 accuracy 0.8125
# Epoch 3 Batch: 119 Loss 0.5542254447937012 accuracy 0.65625
# Epoch 3 Batch: 120 Loss 0.5151761770248413 accuracy 0.6875
# Epoch 3 Batch: 121 Loss 0.5616772770881653 accuracy 0.6875
# Epoch 3 Batch: 122 Loss 0.723599374294281 accuracy 0.625
# Epoch 3 Batch: 123 Loss 0.6965748071670532 accuracy 0.625
# Epoch 3 Batch: 124 Loss 0.49982553720474243 accuracy 0.6875
# Epoch 3 Batch: 125 Loss 0.5345063209533691 accuracy 0.78125
# Epoch 3 Batch: 126 Loss 0.5266172289848328 accuracy 0.71875
# Epoch 3 Batch: 127 Loss 0.5905747413635254 accuracy 0.65625
# Epoch 3 Batch: 128 Loss 0.5581314563751221 accuracy 0.65625
# Epoch 3 Batch: 129 Loss 0.6124721765518188 accuracy 0.6875
# Epoch 3 Batch: 130 Loss 0.5513037443161011 accuracy 0.65625
# Epoch 3 Batch: 131 Loss 0.6568068861961365 accuracy 0.5625
# Epoch 3 Batch: 132 Loss 0.5186634063720703 accuracy 0.78125
# Epoch 3 Batch: 133 Loss 0.5354098081588745 accuracy 0.65625
# Epoch 3 Batch: 134 Loss 0.6963766813278198 accuracy 0.625
# Epoch 3 Batch: 135 Loss 0.6160425543785095 accuracy 0.625
# Epoch 3 Batch: 136 Loss 0.605050265789032 accuracy 0.65625
# Epoch 3 Batch: 137 Loss 0.5894795060157776 accuracy 0.6875
# Epoch 3 Batch: 138 Loss 0.6129133105278015 accuracy 0.625
# Epoch 3 Batch: 139 Loss 0.4654168486595154 accuracy 0.71875
# Epoch 3 Batch: 140 Loss 0.6307594180107117 accuracy 0.59375
# Epoch 3 Batch: 141 Loss 0.46966448426246643 accuracy 0.8125
# Epoch 3 Batch: 142 Loss 0.591532289981842 accuracy 0.65625
# Epoch 3 Batch: 143 Loss 0.4850248694419861 accuracy 0.78125
# Epoch 3 Batch: 144 Loss 0.6003892421722412 accuracy 0.6875
# Epoch 3 Batch: 145 Loss 0.5201596021652222 accuracy 0.71875
# Epoch 3 Batch: 146 Loss 0.4471106231212616 accuracy 0.78125
# Epoch 3 Batch: 147 Loss 0.5745186805725098 accuracy 0.6875
# Epoch 3 Batch: 148 Loss 0.6045203804969788 accuracy 0.6875
# Epoch 3 Batch: 149 Loss 0.4731089472770691 accuracy 0.75
# Epoch 3 Batch: 150 Loss 0.5938927531242371 accuracy 0.65625
# Epoch 3 Batch: 151 Loss 0.49138325452804565 accuracy 0.75
# Epoch 3 Batch: 152 Loss 0.505689263343811 accuracy 0.71875
# Epoch 3 Batch: 153 Loss 0.5371181964874268 accuracy 0.6875
# Epoch 3 Batch: 154 Loss 0.476863294839859 accuracy 0.84375
# Epoch 3 Batch: 155 Loss 0.5771771669387817 accuracy 0.6875
# Epoch 3 Batch: 156 Loss 0.4951375424861908 accuracy 0.75
# Epoch 3 Batch: 157 Loss 0.5553917288780212 accuracy 0.65625
# Epoch 3 Batch: 158 Loss 0.4368031620979309 accuracy 0.78125
# Epoch 3 Batch: 159 Loss 0.6319987177848816 accuracy 0.65625
# Epoch 3 Batch: 160 Loss 0.44640225172042847 accuracy 0.8125
# Epoch 3 Batch: 161 Loss 0.5887659192085266 accuracy 0.71875
# Epoch 3 Batch: 162 Loss 0.652238667011261 accuracy 0.6875
# Epoch 3 Batch: 163 Loss 0.5563316345214844 accuracy 0.71875
# Epoch 3 Batch: 164 Loss 0.403784841299057 accuracy 0.8125
# Epoch 3 Batch: 165 Loss 0.37889692187309265 accuracy 0.84375
# Epoch 3 Batch: 166 Loss 0.6316600441932678 accuracy 0.71875
# Epoch 3 Batch: 167 Loss 0.47505006194114685 accuracy 0.71875
# Epoch 3 Batch: 168 Loss 0.44576770067214966 accuracy 0.78125
# Epoch 3 Batch: 169 Loss 0.40540018677711487 accuracy 0.71875
# Epoch 3 Batch: 170 Loss 0.42902135848999023 accuracy 0.78125
# Epoch 3 Batch: 171 Loss 0.3959570825099945 accuracy 0.90625
# Epoch 3 Batch: 172 Loss 0.525255560874939 accuracy 0.78125
# Epoch 3 Batch: 173 Loss 0.5499392747879028 accuracy 0.65625
# Epoch 3 Batch: 174 Loss 0.3813430070877075 accuracy 0.8125
# Epoch 3 Batch: 175 Loss 0.6581553816795349 accuracy 0.65625
# Epoch 3 Batch: 176 Loss 0.734243631362915 accuracy 0.625
# Epoch 3 Batch: 177 Loss 0.4474870264530182 accuracy 0.78125
# Epoch 3 Batch: 178 Loss 0.3810180127620697 accuracy 0.8125
# Epoch 3 Batch: 179 Loss 0.4804311692714691 accuracy 0.78125
# Epoch 3 Batch: 180 Loss 0.8465356826782227 accuracy 0.53125
# Epoch 3 Batch: 181 Loss 0.5788137912750244 accuracy 0.625
# Epoch 3 Batch: 182 Loss 0.4055570065975189 accuracy 0.84375
# Epoch 3 Batch: 183 Loss 0.6281706690788269 accuracy 0.71875
# Epoch 3 Batch: 184 Loss 0.5504339337348938 accuracy 0.59375
# Epoch 3 Batch: 185 Loss 0.6337586045265198 accuracy 0.5625
# Epoch 3 Batch: 186 Loss 0.3351465165615082 accuracy 0.84375
# Epoch 3 Batch: 187 Loss 0.511940598487854 accuracy 0.75
# Epoch 3 Batch: 188 Loss 0.5315107107162476 accuracy 0.6875
# Epoch 3 Batch: 189 Loss 0.43336021900177 accuracy 0.75
# Epoch 3 Batch: 190 Loss 0.5241683721542358 accuracy 0.6875
# Epoch 3 Batch: 191 Loss 0.6920908689498901 accuracy 0.59375
# Epoch 3 Batch: 192 Loss 0.4093706011772156 accuracy 0.78125
# Epoch 3 Batch: 193 Loss 0.481262743473053 accuracy 0.6875
# Epoch 3 Batch: 194 Loss 0.49790769815444946 accuracy 0.6875
# Epoch 3 Batch: 195 Loss 0.6029325127601624 accuracy 0.71875
# Epoch 3 Batch: 196 Loss 0.4584439694881439 accuracy 0.78125
# Epoch 3 Batch: 197 Loss 0.4712626039981842 accuracy 0.75
# Epoch 3 Batch: 198 Loss 0.6457822322845459 accuracy 0.6875
# Epoch 3 Batch: 199 Loss 0.6809590458869934 accuracy 0.625
# Epoch 3 Batch: 200 Loss 0.534863293170929 accuracy 0.6875
# Epoch 3 Batch: 201 Loss 0.5381300449371338 accuracy 0.71875
# Epoch 3 Batch: 202 Loss 0.47792187333106995 accuracy 0.71875
# Epoch 3 Batch: 203 Loss 0.48946550488471985 accuracy 0.875
# Epoch 3 Batch: 204 Loss 0.6218172311782837 accuracy 0.625
# Epoch 3 Batch: 205 Loss 0.4748728573322296 accuracy 0.78125
# Epoch 3 Batch: 206 Loss 0.47452911734580994 accuracy 0.8125
# Epoch 3 Batch: 207 Loss 0.4164721369743347 accuracy 0.875
# Epoch 3 Batch: 208 Loss 0.3942584991455078 accuracy 0.875
# Epoch 3 Batch: 209 Loss 0.6181141138076782 accuracy 0.625
# Epoch 3 Batch: 210 Loss 0.5078461170196533 accuracy 0.75
# Epoch 3 Batch: 211 Loss 0.7060807943344116 accuracy 0.59375
# Epoch 3 Batch: 212 Loss 0.4335416257381439 accuracy 0.8125
# Epoch 3 Batch: 213 Loss 0.5184275507926941 accuracy 0.71875
# Epoch 3 Batch: 214 Loss 0.5197387933731079 accuracy 0.75
# Epoch 3 Batch: 215 Loss 0.5890800952911377 accuracy 0.71875
# Epoch 3 Batch: 216 Loss 0.5263656377792358 accuracy 0.71875
# Epoch 3 Batch: 217 Loss 0.5356752276420593 accuracy 0.71875
# Epoch 3 Batch: 218 Loss 0.551670491695404 accuracy 0.71875
# Epoch 3 Batch: 219 Loss 0.5353758931159973 accuracy 0.8125
# Epoch 3 Batch: 220 Loss 0.527891993522644 accuracy 0.8125
# Epoch 3 Batch: 221 Loss 0.5060556530952454 accuracy 0.75
# Epoch 3 Batch: 222 Loss 0.3718874752521515 accuracy 0.8125
# Epoch 3 Batch: 223 Loss 0.6627992987632751 accuracy 0.65625
# Epoch 3 Batch: 224 Loss 0.3976707458496094 accuracy 0.75
# Epoch 3 Batch: 225 Loss 0.5643143653869629 accuracy 0.71875
# Epoch 3 Batch: 226 Loss 0.3891216218471527 accuracy 0.875
# Epoch 3 Batch: 227 Loss 0.5276947617530823 accuracy 0.71875
# Epoch 3 Batch: 228 Loss 0.4024757444858551 accuracy 0.8125
# Epoch 3 Batch: 229 Loss 0.5352450013160706 accuracy 0.71875
# Epoch 3 Batch: 230 Loss 0.552429735660553 accuracy 0.71875
# Epoch 3 Batch: 231 Loss 0.5136836767196655 accuracy 0.71875
# Epoch 3 Batch: 232 Loss 0.5188642740249634 accuracy 0.6875
# Epoch 3 Batch: 233 Loss 0.5378219485282898 accuracy 0.6875
# Epoch 3 Batch: 234 Loss 0.544839084148407 accuracy 0.625
# Epoch 3 Batch: 235 Loss 0.49321338534355164 accuracy 0.78125
# Epoch 3 Batch: 236 Loss 0.3122449815273285 accuracy 0.90625
# Epoch 3 Batch: 237 Loss 0.5264657139778137 accuracy 0.75
# Epoch 3 Batch: 238 Loss 0.3064182698726654 accuracy 0.84375
# Epoch 3 Batch: 239 Loss 0.5182732343673706 accuracy 0.6875
# Epoch 3 Batch: 240 Loss 0.5685879588127136 accuracy 0.75
# Epoch 3 Batch: 241 Loss 0.6618207097053528 accuracy 0.625
# Accuracy of train images: 0.6997141372141372
# E:3, Train Loss:0.5521415943179387
# Epoch 3 Accuracy of val1 images: 0.8108348134991119
# Epoch 3 Val1 Loss: 0.3884788586033715
# Epoch 3 Accuracy of val2 images: 0.8049702863317126
# Epoch 3 Val2 Loss: 0.4110376416095372
# Epoch 4 Batch: 1 Loss 0.31747812032699585 accuracy 0.9375
# Epoch 4 Batch: 2 Loss 0.4801444411277771 accuracy 0.75
# Epoch 4 Batch: 3 Loss 0.4765787422657013 accuracy 0.8125
# Epoch 4 Batch: 4 Loss 0.5864070057868958 accuracy 0.71875
# Epoch 4 Batch: 5 Loss 0.5692073702812195 accuracy 0.5625
# Epoch 4 Batch: 6 Loss 0.5369774699211121 accuracy 0.71875
# Epoch 4 Batch: 7 Loss 0.40691059827804565 accuracy 0.875
# Epoch 4 Batch: 8 Loss 0.5518437623977661 accuracy 0.71875
# Epoch 4 Batch: 9 Loss 0.4739918112754822 accuracy 0.71875
# Epoch 4 Batch: 10 Loss 0.5770289301872253 accuracy 0.625
# Epoch 4 Batch: 11 Loss 0.5245636701583862 accuracy 0.6875
# Epoch 4 Batch: 12 Loss 0.5005486607551575 accuracy 0.6875
# Epoch 4 Batch: 13 Loss 0.5437623262405396 accuracy 0.625
# Epoch 4 Batch: 14 Loss 0.5249914526939392 accuracy 0.75
# Epoch 4 Batch: 15 Loss 0.37856200337409973 accuracy 0.8125
# Epoch 4 Batch: 16 Loss 0.40604710578918457 accuracy 0.84375
# Epoch 4 Batch: 17 Loss 0.4654516279697418 accuracy 0.75
# Epoch 4 Batch: 18 Loss 0.4625939130783081 accuracy 0.8125
# Epoch 4 Batch: 19 Loss 0.4832777678966522 accuracy 0.75
# Epoch 4 Batch: 20 Loss 0.2995358109474182 accuracy 0.9375
# Epoch 4 Batch: 21 Loss 0.7560930252075195 accuracy 0.5625
# Epoch 4 Batch: 22 Loss 0.6438423991203308 accuracy 0.625
# Epoch 4 Batch: 23 Loss 0.4910792112350464 accuracy 0.875
# Epoch 4 Batch: 24 Loss 0.539662778377533 accuracy 0.65625
# Epoch 4 Batch: 25 Loss 0.45107078552246094 accuracy 0.84375
# Epoch 4 Batch: 26 Loss 0.6037391424179077 accuracy 0.65625
# Epoch 4 Batch: 27 Loss 0.4035864472389221 accuracy 0.78125
# Epoch 4 Batch: 28 Loss 0.49652037024497986 accuracy 0.78125
# Epoch 4 Batch: 29 Loss 0.49846985936164856 accuracy 0.78125
# Epoch 4 Batch: 30 Loss 0.5055718421936035 accuracy 0.71875
# Epoch 4 Batch: 31 Loss 0.4419556260108948 accuracy 0.8125
# Epoch 4 Batch: 32 Loss 0.5312884449958801 accuracy 0.6875
# Epoch 4 Batch: 33 Loss 0.4474523663520813 accuracy 0.8125
# Epoch 4 Batch: 34 Loss 0.41608503460884094 accuracy 0.8125
# Epoch 4 Batch: 35 Loss 0.5490440130233765 accuracy 0.78125
# Epoch 4 Batch: 36 Loss 0.41041335463523865 accuracy 0.8125
# Epoch 4 Batch: 37 Loss 0.33434098958969116 accuracy 0.875
# Epoch 4 Batch: 38 Loss 0.49839696288108826 accuracy 0.78125
# Epoch 4 Batch: 39 Loss 0.44755029678344727 accuracy 0.78125
# Epoch 4 Batch: 40 Loss 0.34065309166908264 accuracy 0.8125
# Epoch 4 Batch: 41 Loss 0.599369466304779 accuracy 0.625
# Epoch 4 Batch: 42 Loss 0.46120306849479675 accuracy 0.75
# Epoch 4 Batch: 43 Loss 0.684342086315155 accuracy 0.65625
# Epoch 4 Batch: 44 Loss 0.43794959783554077 accuracy 0.75
# Epoch 4 Batch: 45 Loss 0.48916730284690857 accuracy 0.75
# Epoch 4 Batch: 46 Loss 0.5257604122161865 accuracy 0.71875
# Epoch 4 Batch: 47 Loss 0.41309958696365356 accuracy 0.875
# Epoch 4 Batch: 48 Loss 0.5282171368598938 accuracy 0.6875
# Epoch 4 Batch: 49 Loss 0.4979172348976135 accuracy 0.71875
# Epoch 4 Batch: 50 Loss 0.5249397158622742 accuracy 0.6875
# Epoch 4 Batch: 51 Loss 0.436442106962204 accuracy 0.84375
# Epoch 4 Batch: 52 Loss 0.4469301402568817 accuracy 0.78125
# Epoch 4 Batch: 53 Loss 0.4274182915687561 accuracy 0.8125
# Epoch 4 Batch: 54 Loss 0.5063548684120178 accuracy 0.625
# Epoch 4 Batch: 55 Loss 0.4059343934059143 accuracy 0.78125
# Epoch 4 Batch: 56 Loss 0.31354913115501404 accuracy 0.90625
# Epoch 4 Batch: 57 Loss 0.5064270496368408 accuracy 0.75
# Epoch 4 Batch: 58 Loss 0.5937683582305908 accuracy 0.71875
# Epoch 4 Batch: 59 Loss 0.4108335077762604 accuracy 0.78125
# Epoch 4 Batch: 60 Loss 0.49351680278778076 accuracy 0.71875
# Epoch 4 Batch: 61 Loss 0.49225082993507385 accuracy 0.8125
# Epoch 4 Batch: 62 Loss 0.4790562689304352 accuracy 0.875
# Epoch 4 Batch: 63 Loss 0.5573688745498657 accuracy 0.65625
# Epoch 4 Batch: 64 Loss 0.6080304980278015 accuracy 0.75
# Epoch 4 Batch: 65 Loss 0.4583348333835602 accuracy 0.78125
# Epoch 4 Batch: 66 Loss 0.47159314155578613 accuracy 0.6875
# Epoch 4 Batch: 67 Loss 0.581943154335022 accuracy 0.65625
# Epoch 4 Batch: 68 Loss 0.6030575633049011 accuracy 0.75
# Epoch 4 Batch: 69 Loss 0.5288139581680298 accuracy 0.6875
# Epoch 4 Batch: 70 Loss 0.42035627365112305 accuracy 0.84375
# Epoch 4 Batch: 71 Loss 0.5960267782211304 accuracy 0.65625
# Epoch 4 Batch: 72 Loss 0.4690135419368744 accuracy 0.78125
# Epoch 4 Batch: 73 Loss 0.28667008876800537 accuracy 0.9375
# Epoch 4 Batch: 74 Loss 0.3089370131492615 accuracy 0.875
# Epoch 4 Batch: 75 Loss 0.501200795173645 accuracy 0.8125
# Epoch 4 Batch: 76 Loss 0.5412992238998413 accuracy 0.75
# ...
# Epoch 14 Batch: 83 Loss 0.20473703742027283 accuracy 0.875
# Epoch 14 Batch: 84 Loss 0.14734216034412384 accuracy 0.96875
# Epoch 14 Batch: 85 Loss 0.25223398208618164 accuracy 0.90625
# Epoch 14 Batch: 86 Loss 0.2727890908718109 accuracy 0.875
# Epoch 14 Batch: 87 Loss 0.14012791216373444 accuracy 0.9375
# Epoch 14 Batch: 88 Loss 0.29421961307525635 accuracy 0.8125
# Epoch 14 Batch: 89 Loss 0.25359922647476196 accuracy 0.875
# Epoch 14 Batch: 90 Loss 0.37628981471061707 accuracy 0.8125
# Epoch 14 Batch: 91 Loss 0.3420335650444031 accuracy 0.9375
# Epoch 14 Batch: 92 Loss 0.17313550412654877 accuracy 0.9375
# Epoch 14 Batch: 93 Loss 0.48699939250946045 accuracy 0.6875
# Epoch 14 Batch: 94 Loss 0.12081357836723328 accuracy 0.9375
# Epoch 14 Batch: 95 Loss 0.313128262758255 accuracy 0.90625
# Epoch 14 Batch: 96 Loss 0.2998676002025604 accuracy 0.875
# Epoch 14 Batch: 97 Loss 0.16723355650901794 accuracy 1.0
# Epoch 14 Batch: 98 Loss 0.20649096369743347 accuracy 0.9375
# Epoch 14 Batch: 99 Loss 0.29568707942962646 accuracy 0.90625
# Epoch 14 Batch: 100 Loss 0.3054913282394409 accuracy 0.9375
# Epoch 14 Batch: 101 Loss 0.22626276314258575 accuracy 0.875
# Epoch 14 Batch: 102 Loss 0.35532212257385254 accuracy 0.84375
# Epoch 14 Batch: 103 Loss 0.20880162715911865 accuracy 0.96875
# Epoch 14 Batch: 104 Loss 0.18248192965984344 accuracy 0.96875
# Epoch 14 Batch: 105 Loss 0.23856821656227112 accuracy 0.875
# Epoch 14 Batch: 106 Loss 0.6541064381599426 accuracy 0.8125
# Epoch 14 Batch: 107 Loss 0.11835918575525284 accuracy 0.9375
# Epoch 14 Batch: 108 Loss 0.202077254652977 accuracy 0.96875
# Epoch 14 Batch: 109 Loss 0.1425955444574356 accuracy 0.9375
# Epoch 14 Batch: 110 Loss 0.31103524565696716 accuracy 0.84375
# Epoch 14 Batch: 111 Loss 0.1573895961046219 accuracy 0.9375
# Epoch 14 Batch: 112 Loss 0.15763740241527557 accuracy 0.9375
# Epoch 14 Batch: 113 Loss 0.12940678000450134 accuracy 0.96875
# Epoch 14 Batch: 114 Loss 0.1703636795282364 accuracy 0.9375
# Epoch 14 Batch: 115 Loss 0.30009332299232483 accuracy 0.84375
# Epoch 14 Batch: 116 Loss 0.34935474395751953 accuracy 0.84375
# Epoch 14 Batch: 117 Loss 0.2677992880344391 accuracy 0.875
# Epoch 14 Batch: 118 Loss 0.27847254276275635 accuracy 0.84375
# Epoch 14 Batch: 119 Loss 0.33269795775413513 accuracy 0.8125
# Epoch 14 Batch: 120 Loss 0.3417949378490448 accuracy 0.8125
# Epoch 14 Batch: 121 Loss 0.36410853266716003 accuracy 0.84375
# Epoch 14 Batch: 122 Loss 0.3715749680995941 accuracy 0.78125
# Epoch 14 Batch: 123 Loss 0.21512307226657867 accuracy 0.90625
# Epoch 14 Batch: 124 Loss 0.33310243487358093 accuracy 0.84375
# Epoch 14 Batch: 125 Loss 0.24040357768535614 accuracy 0.875
# Epoch 14 Batch: 126 Loss 0.47519242763519287 accuracy 0.8125
# Epoch 14 Batch: 127 Loss 0.23672425746917725 accuracy 0.875
# Epoch 14 Batch: 128 Loss 0.26396647095680237 accuracy 0.8125
# Epoch 14 Batch: 129 Loss 0.18998992443084717 accuracy 0.9375
# Epoch 14 Batch: 130 Loss 0.322401225566864 accuracy 0.8125
# Epoch 14 Batch: 131 Loss 0.20552219450473785 accuracy 0.90625
# Epoch 14 Batch: 132 Loss 0.1120036393404007 accuracy 0.9375
# Epoch 14 Batch: 133 Loss 0.20620834827423096 accuracy 0.875
# Epoch 14 Batch: 134 Loss 0.19091874361038208 accuracy 0.9375
# Epoch 14 Batch: 135 Loss 0.22407780587673187 accuracy 0.90625
# Epoch 14 Batch: 136 Loss 0.25823667645454407 accuracy 0.90625
# Epoch 14 Batch: 137 Loss 0.19403046369552612 accuracy 0.90625
# Epoch 14 Batch: 138 Loss 0.21650978922843933 accuracy 0.9375
# Epoch 14 Batch: 139 Loss 0.31681984663009644 accuracy 0.875
# Epoch 14 Batch: 140 Loss 0.2577565014362335 accuracy 0.84375
# Epoch 14 Batch: 141 Loss 0.26736196875572205 accuracy 0.875
# Epoch 14 Batch: 142 Loss 0.16559971868991852 accuracy 0.9375
# Epoch 14 Batch: 143 Loss 0.2749261260032654 accuracy 0.90625
# Epoch 14 Batch: 144 Loss 0.2029792070388794 accuracy 0.90625
# Epoch 14 Batch: 145 Loss 0.19141899049282074 accuracy 0.875
# Epoch 14 Batch: 146 Loss 0.4032183289527893 accuracy 0.8125
# Epoch 14 Batch: 147 Loss 0.3712086081504822 accuracy 0.875
# Epoch 14 Batch: 148 Loss 0.21425144374370575 accuracy 0.90625
# Epoch 14 Batch: 149 Loss 0.23395492136478424 accuracy 0.84375
# Epoch 14 Batch: 150 Loss 0.29548561573028564 accuracy 0.875
# Epoch 14 Batch: 151 Loss 0.30171138048171997 accuracy 0.8125
# Epoch 14 Batch: 152 Loss 0.23160116374492645 accuracy 0.875
# Epoch 14 Batch: 153 Loss 0.30629682540893555 accuracy 0.875
# Epoch 14 Batch: 154 Loss 0.4279536306858063 accuracy 0.84375
# Epoch 14 Batch: 155 Loss 0.7465556263923645 accuracy 0.71875
# Epoch 14 Batch: 156 Loss 0.4949658215045929 accuracy 0.78125
# Epoch 14 Batch: 157 Loss 0.09999346733093262 accuracy 0.96875
# Epoch 14 Batch: 158 Loss 0.37674370408058167 accuracy 0.84375
# Epoch 14 Batch: 159 Loss 0.17753006517887115 accuracy 0.90625
# Epoch 14 Batch: 160 Loss 0.3885030448436737 accuracy 0.875
# Epoch 14 Batch: 161 Loss 0.09211739897727966 accuracy 0.96875
# Epoch 14 Batch: 162 Loss 0.2870173156261444 accuracy 0.84375
# Epoch 14 Batch: 163 Loss 0.06755968183279037 accuracy 1.0
# Epoch 14 Batch: 164 Loss 0.12081845849752426 accuracy 0.96875
# Epoch 14 Batch: 165 Loss 0.36006468534469604 accuracy 0.84375
# Epoch 14 Batch: 166 Loss 0.1540198028087616 accuracy 0.9375
# Epoch 14 Batch: 167 Loss 0.19501212239265442 accuracy 0.90625
# Epoch 14 Batch: 168 Loss 0.35449907183647156 accuracy 0.8125
# Epoch 14 Batch: 169 Loss 0.23823943734169006 accuracy 0.875
# Epoch 14 Batch: 170 Loss 0.23654696345329285 accuracy 0.875
# Epoch 14 Batch: 171 Loss 0.29468509554862976 accuracy 0.875
# Epoch 14 Batch: 172 Loss 0.10721848905086517 accuracy 0.96875
# Epoch 14 Batch: 173 Loss 0.30505040287971497 accuracy 0.9375
# Epoch 14 Batch: 174 Loss 0.19058911502361298 accuracy 0.875
# Epoch 14 Batch: 175 Loss 0.31207552552223206 accuracy 0.90625
# Epoch 14 Batch: 176 Loss 0.2891080975532532 accuracy 0.78125
# Epoch 14 Batch: 177 Loss 0.2644328773021698 accuracy 0.90625
# Epoch 14 Batch: 178 Loss 0.5308831334114075 accuracy 0.8125
# Epoch 14 Batch: 179 Loss 0.21048665046691895 accuracy 0.96875
# Epoch 14 Batch: 180 Loss 0.16367942094802856 accuracy 0.9375
# Epoch 14 Batch: 181 Loss 0.26050278544425964 accuracy 0.90625
# Epoch 14 Batch: 182 Loss 0.26591727137565613 accuracy 0.90625
# Epoch 14 Batch: 183 Loss 0.1738642156124115 accuracy 0.9375
# Epoch 14 Batch: 184 Loss 0.293125718832016 accuracy 0.8125
# Epoch 14 Batch: 185 Loss 0.19327324628829956 accuracy 0.875
# Epoch 14 Batch: 186 Loss 0.30649256706237793 accuracy 0.875
# Epoch 14 Batch: 187 Loss 0.46989700198173523 accuracy 0.84375
# Epoch 14 Batch: 188 Loss 0.2542404234409332 accuracy 0.9375
# Epoch 14 Batch: 189 Loss 0.16728171706199646 accuracy 0.9375
# Epoch 14 Batch: 190 Loss 0.21465198695659637 accuracy 0.875
# Epoch 14 Batch: 191 Loss 0.2798629403114319 accuracy 0.9375
# Epoch 14 Batch: 192 Loss 0.20378723740577698 accuracy 0.875
# Epoch 14 Batch: 193 Loss 0.43041667342185974 accuracy 0.78125
# Epoch 14 Batch: 194 Loss 0.2024836540222168 accuracy 0.96875
# Epoch 14 Batch: 195 Loss 0.20326678454875946 accuracy 0.90625
# Epoch 14 Batch: 196 Loss 0.3990600109100342 accuracy 0.84375
# Epoch 14 Batch: 197 Loss 0.2612895369529724 accuracy 0.875
# Epoch 14 Batch: 198 Loss 0.1278267800807953 accuracy 0.96875
# Epoch 14 Batch: 199 Loss 0.19090574979782104 accuracy 0.9375
# Epoch 14 Batch: 200 Loss 0.19264382123947144 accuracy 0.90625
# Epoch 14 Batch: 201 Loss 0.15429475903511047 accuracy 0.9375
# Epoch 14 Batch: 202 Loss 0.14684820175170898 accuracy 0.90625
# Epoch 14 Batch: 203 Loss 0.20088014006614685 accuracy 0.96875
# Epoch 14 Batch: 204 Loss 0.16316093504428864 accuracy 0.96875
# Epoch 14 Batch: 205 Loss 0.33868852257728577 accuracy 0.90625
# Epoch 14 Batch: 206 Loss 0.3099239468574524 accuracy 0.84375
# Epoch 14 Batch: 207 Loss 0.2424687147140503 accuracy 0.84375
# Epoch 14 Batch: 208 Loss 0.30313533544540405 accuracy 0.8125
# Epoch 14 Batch: 209 Loss 0.18443584442138672 accuracy 0.9375
# Epoch 14 Batch: 210 Loss 0.31482693552970886 accuracy 0.84375
# Epoch 14 Batch: 211 Loss 0.14155341684818268 accuracy 0.9375
# Epoch 14 Batch: 212 Loss 0.22345870733261108 accuracy 0.9375
# Epoch 14 Batch: 213 Loss 0.3026544749736786 accuracy 0.8125
# Epoch 14 Batch: 214 Loss 0.2450554221868515 accuracy 0.90625
# Epoch 14 Batch: 215 Loss 0.10893455147743225 accuracy 0.96875
# Epoch 14 Batch: 216 Loss 0.13469882309436798 accuracy 0.9375
# Epoch 14 Batch: 217 Loss 0.35446685552597046 accuracy 0.84375
# Epoch 14 Batch: 218 Loss 0.22373127937316895 accuracy 0.90625
# Epoch 14 Batch: 219 Loss 0.29945600032806396 accuracy 0.90625
# Epoch 14 Batch: 220 Loss 0.21809963881969452 accuracy 0.90625
# Epoch 14 Batch: 221 Loss 0.18660378456115723 accuracy 0.9375
# Epoch 14 Batch: 222 Loss 0.3175228238105774 accuracy 0.84375
# Epoch 14 Batch: 223 Loss 0.21849845349788666 accuracy 0.84375
# Epoch 14 Batch: 224 Loss 0.25434622168540955 accuracy 0.875
# Epoch 14 Batch: 225 Loss 0.31276214122772217 accuracy 0.84375
# Epoch 14 Batch: 226 Loss 0.35761532187461853 accuracy 0.8125
# Epoch 14 Batch: 227 Loss 0.24524329602718353 accuracy 0.90625
# Epoch 14 Batch: 228 Loss 0.25719761848449707 accuracy 0.9375
# Epoch 14 Batch: 229 Loss 0.35078105330467224 accuracy 0.9375
# Epoch 14 Batch: 230 Loss 0.17822112143039703 accuracy 0.90625
# Epoch 14 Batch: 231 Loss 0.46268442273139954 accuracy 0.8125
# Epoch 14 Batch: 232 Loss 0.29065489768981934 accuracy 0.90625
# Epoch 14 Batch: 233 Loss 0.4254637062549591 accuracy 0.78125
# Epoch 14 Batch: 234 Loss 0.12794071435928345 accuracy 0.96875
# Epoch 14 Batch: 235 Loss 0.10207460075616837 accuracy 1.0
# Epoch 14 Batch: 236 Loss 0.21808095276355743 accuracy 0.90625
# Epoch 14 Batch: 237 Loss 0.22495591640472412 accuracy 0.90625
# Epoch 14 Batch: 238 Loss 0.22331994771957397 accuracy 0.90625
# Epoch 14 Batch: 239 Loss 0.19160816073417664 accuracy 0.9375
# Epoch 14 Batch: 240 Loss 0.2689364552497864 accuracy 0.90625
# Epoch 14 Batch: 241 Loss 0.37329044938087463 accuracy 0.8125
# Accuracy of train images: 0.8929313929313929
# E:14, Train Loss:0.25515969657180715
# Epoch 14 Accuracy of val1 images: 0.91651865008881
# Epoch 14 Val1 Loss: 0.20290576480329037
# Epoch 14 Accuracy of val2 images: 0.9081577525661805
# Epoch 14 Val2 Loss: 0.2325640362526836
# Epoch 15 Batch: 1 Loss 0.365754634141922 accuracy 0.90625
# Epoch 15 Batch: 2 Loss 0.3331727683544159 accuracy 0.875
# Epoch 15 Batch: 3 Loss 0.12148287892341614 accuracy 0.96875
# Epoch 15 Batch: 4 Loss 0.3484569489955902 accuracy 0.875
# Epoch 15 Batch: 5 Loss 0.23067042231559753 accuracy 0.90625
# Epoch 15 Batch: 6 Loss 0.34741654992103577 accuracy 0.8125
# Epoch 15 Batch: 7 Loss 0.09379991143941879 accuracy 0.96875
# Epoch 15 Batch: 8 Loss 0.1479426920413971 accuracy 0.96875
# Epoch 15 Batch: 9 Loss 0.14229214191436768 accuracy 0.9375
# Epoch 15 Batch: 10 Loss 0.29795870184898376 accuracy 0.84375
# Epoch 15 Batch: 11 Loss 0.3307670056819916 accuracy 0.875
# Epoch 15 Batch: 12 Loss 0.27380236983299255 accuracy 0.84375
# Epoch 15 Batch: 13 Loss 0.08468884974718094 accuracy 1.0
# Epoch 15 Batch: 14 Loss 0.17174676060676575 accuracy 0.9375
# Epoch 15 Batch: 15 Loss 0.12565459311008453 accuracy 1.0
# Epoch 15 Batch: 16 Loss 0.2922602891921997 accuracy 0.875
# Epoch 15 Batch: 17 Loss 0.6470638513565063 accuracy 0.65625
# Epoch 15 Batch: 18 Loss 0.492553174495697 accuracy 0.75
# Epoch 15 Batch: 19 Loss 0.2660980522632599 accuracy 0.875
# Epoch 15 Batch: 20 Loss 0.3676459491252899 accuracy 0.78125
# Epoch 15 Batch: 21 Loss 0.4364835321903229 accuracy 0.78125
# Epoch 15 Batch: 22 Loss 0.11187581717967987 accuracy 1.0
# Epoch 15 Batch: 23 Loss 0.2758345305919647 accuracy 0.90625
# Epoch 15 Batch: 24 Loss 0.21321287751197815 accuracy 0.9375
# Epoch 15 Batch: 25 Loss 0.20901882648468018 accuracy 0.90625
# Epoch 15 Batch: 26 Loss 0.3507692813873291 accuracy 0.875
# Epoch 15 Batch: 27 Loss 0.33730050921440125 accuracy 0.875
# Epoch 15 Batch: 28 Loss 0.2634512186050415 accuracy 0.875
# Epoch 15 Batch: 29 Loss 0.1845608353614807 accuracy 0.96875
# Epoch 15 Batch: 30 Loss 0.4944947063922882 accuracy 0.78125
# Epoch 15 Batch: 31 Loss 0.28967270255088806 accuracy 0.875
# Epoch 15 Batch: 32 Loss 0.3092387020587921 accuracy 0.84375
# Epoch 15 Batch: 33 Loss 0.26608431339263916 accuracy 0.90625
# Epoch 15 Batch: 34 Loss 0.34032201766967773 accuracy 0.8125
# Epoch 15 Batch: 35 Loss 0.21590957045555115 accuracy 0.90625
# Epoch 15 Batch: 36 Loss 0.23374934494495392 accuracy 0.90625
# Epoch 15 Batch: 37 Loss 0.4024431109428406 accuracy 0.8125
# Epoch 15 Batch: 38 Loss 0.40404337644577026 accuracy 0.78125
# Epoch 15 Batch: 39 Loss 0.08604564517736435 accuracy 1.0
# Epoch 15 Batch: 40 Loss 0.20593492686748505 accuracy 0.90625
# Epoch 15 Batch: 41 Loss 0.21662947535514832 accuracy 0.875
# Epoch 15 Batch: 42 Loss 0.20981194078922272 accuracy 0.90625
# Epoch 15 Batch: 43 Loss 0.36450618505477905 accuracy 0.8125
# Epoch 15 Batch: 44 Loss 0.3652959167957306 accuracy 0.84375
# Epoch 15 Batch: 45 Loss 0.4105401337146759 accuracy 0.78125
# Epoch 15 Batch: 46 Loss 0.2654370665550232 accuracy 0.875
# Epoch 15 Batch: 47 Loss 0.35082361102104187 accuracy 0.84375
# Epoch 15 Batch: 48 Loss 0.3143247663974762 accuracy 0.8125
# Epoch 15 Batch: 49 Loss 0.16174200177192688 accuracy 0.9375
# Epoch 15 Batch: 50 Loss 0.3328111171722412 accuracy 0.875
# Epoch 15 Batch: 51 Loss 0.17445708811283112 accuracy 0.9375
# Epoch 15 Batch: 52 Loss 0.30834057927131653 accuracy 0.8125
# Epoch 15 Batch: 53 Loss 0.27423232793807983 accuracy 0.875
# Epoch 15 Batch: 54 Loss 0.33175432682037354 accuracy 0.875
# Epoch 15 Batch: 55 Loss 0.3843594491481781 accuracy 0.84375
# Epoch 15 Batch: 56 Loss 0.21515537798404694 accuracy 0.9375
# Epoch 15 Batch: 57 Loss 0.09627147018909454 accuracy 0.96875
# Epoch 15 Batch: 58 Loss 0.3059101700782776 accuracy 0.9375
# Epoch 15 Batch: 59 Loss 0.2537868618965149 accuracy 0.90625
# Epoch 15 Batch: 60 Loss 0.22690843045711517 accuracy 0.9375
# Epoch 15 Batch: 61 Loss 0.3686242699623108 accuracy 0.90625
# Epoch 15 Batch: 62 Loss 0.24613475799560547 accuracy 0.84375
# Epoch 15 Batch: 63 Loss 0.2647128403186798 accuracy 0.84375
# Epoch 15 Batch: 64 Loss 0.1975817233324051 accuracy 0.90625
# Epoch 15 Batch: 65 Loss 0.2192106544971466 accuracy 0.9375
# Epoch 15 Batch: 66 Loss 0.5729653239250183 accuracy 0.84375
# Epoch 15 Batch: 67 Loss 0.21382950246334076 accuracy 0.9375
# Epoch 15 Batch: 68 Loss 0.31664708256721497 accuracy 0.8125
# Epoch 15 Batch: 69 Loss 0.3376869559288025 accuracy 0.875
# Epoch 15 Batch: 70 Loss 0.29387691617012024 accuracy 0.90625
# Epoch 15 Batch: 71 Loss 0.07852735370397568 accuracy 1.0
# Epoch 15 Batch: 72 Loss 0.45397675037384033 accuracy 0.875
# Epoch 15 Batch: 73 Loss 0.3102595806121826 accuracy 0.90625
# Epoch 15 Batch: 74 Loss 0.2541588544845581 accuracy 0.9375
# Epoch 15 Batch: 75 Loss 0.4654909670352936 accuracy 0.6875
# Epoch 15 Batch: 76 Loss 0.25812843441963196 accuracy 0.875
# Epoch 15 Batch: 77 Loss 0.1289752721786499 accuracy 0.96875
# Epoch 15 Batch: 78 Loss 0.1682198941707611 accuracy 0.96875
# Epoch 15 Batch: 79 Loss 0.248606875538826 accuracy 0.90625
# Epoch 15 Batch: 80 Loss 0.20792517066001892 accuracy 0.875
# Epoch 15 Batch: 81 Loss 0.2298421710729599 accuracy 0.90625
# Epoch 15 Batch: 82 Loss 0.1311357021331787 accuracy 0.96875
# Epoch 15 Batch: 83 Loss 0.2181386500597 accuracy 0.90625
# Epoch 15 Batch: 84 Loss 0.23716121912002563 accuracy 0.90625
# Epoch 15 Batch: 85 Loss 0.2952693998813629 accuracy 0.84375
# Epoch 15 Batch: 86 Loss 0.4921756386756897 accuracy 0.78125
# Epoch 15 Batch: 87 Loss 0.24165575206279755 accuracy 0.90625
# Epoch 15 Batch: 88 Loss 0.1943359524011612 accuracy 0.90625
# Epoch 15 Batch: 89 Loss 0.23198118805885315 accuracy 0.90625
# Epoch 15 Batch: 90 Loss 0.40881696343421936 accuracy 0.78125
# Epoch 15 Batch: 91 Loss 0.2888033092021942 accuracy 0.875
# Epoch 15 Batch: 92 Loss 0.18511295318603516 accuracy 0.90625
# Epoch 15 Batch: 93 Loss 0.321183979511261 accuracy 0.84375
# Epoch 15 Batch: 94 Loss 0.15950293838977814 accuracy 0.9375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-4e22724d995d> in <module>()
#      22         loss.backward()
#      23         optimizer.step()
# ---> 24         running_loss += loss.item()
#      25         train_accuracy = correct / total
#      26         train_loss = running_loss / batch_count
#
# KeyboardInterrupt:

# %%
#learing rate
#lr sheduling

# %%
model_ft.eval()
correct = 0
total = 0
val_loss = 0.0
batch_count = 0
with torch.no_grad():
    for data in test1_data:
        batch_count+=1
        images, labels = data
        labels = labels.type(torch.LongTensor)
        images = images.to(device)
        labels = labels.to(device)
        outputs = model_ft(images)  
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item() 
        loss = criterion(outputs,labels)       
        val_loss += loss.item()
val_loss /= batch_count
print('Accuracy of test1 images: {}'.format(  correct / total))
print('test1 Loss: {}'.format( val_loss))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-62c7435bd25e> in <module>()
#       5 batch_count = 0
#       6 with torch.no_grad():
# ----> 7     for data in test1_data:
#       8         batch_count+=1
#       9         images, labels = data
#
# NameError: name 'test1_data' is not defined
